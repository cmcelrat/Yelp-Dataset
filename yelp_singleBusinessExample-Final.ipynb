# %% [markdown]
# # Multilabel Classification on Yelp Restaurant Reviews for Segmented Sentiment Analysis
# ***
# #### Training and applying a neural network model to label restaurant reviews as: Service, Food, Miscellaneous, and/or Ambience. <br> After reviews are segmented by topic, a restaurant could analyze in which categories they are underperforming to know where resources should be devoted for improvement
# ***

# %% [markdown]
# ### Environment Set-up

# %%
import os
import pandas as pd
import numpy as np

# %%
import gensim.parsing.preprocessing as preprocessing
from gensim.utils import simple_preprocess
import nltk
nltk.download('omw-1.4')
from nltk.tokenize import word_tokenize
nltk.download(["averaged_perceptron_tagger", "wordnet", "punkt"])

from tqdm.auto import tqdm
tqdm.pandas()
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Caitl\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Caitl\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Caitl\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Caitl\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import string

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Bidirectional

# %%
from sklearn.model_selection import train_test_split

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')

# %% [markdown]
# ## Phase 1: Train Model on Labeled Dataset

# %% [markdown]
# ### Import Labeled Data

# %%
labeled_data = pd.read_excel("semeval2014_added.xlsx")
labeled_data

# Downloaded a previously labeled dataset and added more labeled samples to it
#https://github.com/Lucasfrota/MultilabelClassificationExample/blob/master/semeval2014.csv
# Out:
#                                                    text  service  food  \
# 0                   but the staff was so horrible to us        1     0
# 1     to be completely fair the only redeeming facto...        0     1
# 2     the food is uniformly exceptional with a very ...        0     1
# 3     where gabriela personaly greets you and recomm...        1     0
# 4     for those that go once and dont enjoy it all i...        0     0
# ...                                                 ...      ...   ...
# 3814  Thank you again to the nice host, your company...        1     0
# 3815                  The setting is dark and romantic.        0     0
# 3816  There is dreamy lighting and a bubbling water ...        0     0
# 3817                    The dish layouts are beautiful.        0     1
# 3818  The sushi entrees choices could have more opti...        0     1
#
#       anecdotes/miscellaneous  price  ambience
# 0                           0      0         0
# 1                           1      0         0
# 2                           0      0         0
# 3                           0      0         0
# 4                           1      0         0
# ...                       ...    ...       ...
# 3814                        0      0         0
# 3815                        0      0         1
# 3816                        0      0         1
# 3817                        0      0         0
# 3818                        0      1         0
#
# [3819 rows x 6 columns]

# %% [markdown]
# ### Preprocess text by simplifying and tokenizing

# %%
def lemmatize_text(token_list, wnl):
  # POS tag each word
  for word, tag in nltk.pos_tag(token_list):
    # Mapping the pos tags to the types supported by wnl
    if tag.startswith("NN"):
      yield wnl.lemmatize(word, pos='n')
    elif tag.startswith('VB'):
      yield wnl.lemmatize(word, pos='v')
    elif tag.startswith('JJ'):
      yield wnl.lemmatize(word, pos='a')
    elif tag.startswith('RB'):
      yield wnl.lemmatize(word, pos='r')
    else:
      yield wnl.lemmatize(word)

# lower letters, strip_multiple_whitespaces, and stopwords
CUSTOM_FILTERS = [lambda x: x.lower(), preprocessing.strip_multiple_whitespaces, preprocessing.remove_stopwords]
labeled_data["processed_text"] = labeled_data["text"].apply(lambda x: preprocessing.preprocess_string(x, CUSTOM_FILTERS))

# lemmatize the tokens
wnl = nltk.WordNetLemmatizer()
labeled_data["processed_text"] = labeled_data["processed_text"].progress_apply(lambda x: simple_preprocess(" ".join(lemmatize_text(x, wnl))))
# Out:
#   0%|          | 0/3819 [00:00<?, ?it/s]

# %%
# Checking tokenization
labeled_data
# Out:
#                                                    text  service  food  \
# 0                   but the staff was so horrible to us        1     0
# 1     to be completely fair the only redeeming facto...        0     1
# 2     the food is uniformly exceptional with a very ...        0     1
# 3     where gabriela personaly greets you and recomm...        1     0
# 4     for those that go once and dont enjoy it all i...        0     0
# ...                                                 ...      ...   ...
# 3814  Thank you again to the nice host, your company...        1     0
# 3815                  The setting is dark and romantic.        0     0
# 3816  There is dreamy lighting and a bubbling water ...        0     0
# 3817                    The dish layouts are beautiful.        0     1
# 3818  The sushi entrees choices could have more opti...        0     1
#
#       anecdotes/miscellaneous  price  ambience  \
# 0                           0      0         0
# 1                           1      0         0
# 2                           0      0         0
# 3                           0      0         0
# 4                           1      0         0
# ...                       ...    ...       ...
# 3814                        0      0         0
# 3815                        0      0         1
# 3816                        0      0         1
# 3817                        0      0         0
# 3818                        0      1         0
#
#                                          processed_text
# 0                                     [staff, horrible]
# 1     [completely, fair, redeem, factor, food, avera...
# 2     [food, uniformly, exceptional, capable, kitche...
# 3         [gabriela, personaly, greets, recommend, eat]
# 4                                   [dont, enjoy, dont]
# ...                                                 ...
# 3814  [thank, nice, host, company, conversation, enj...
# 3815                              [set, dark, romantic]
# 3816  [dreamy, light, bubbling, water, fountain, cor...
# 3817                          [dish, layout, beautiful]
# 3818  [sushi, entree, choice, option, sushi, taste, ...
#
# [3819 rows x 7 columns]

# %% [markdown]
# ### Create Word Embeddings

# %%
# Using GloVe
embeddings_dict = {}
with open("glove.6B.50d.txt", 'r', encoding='utf-8') as f:
    for line in f:
        values = line.split()
        word = values[0]
        vector = np.asarray(values[1:], "float32")
        embeddings_dict[word] = vector

# %%
# Testing max length of review sentences in this labeled dataset
list_of_texts = labeled_data['processed_text']

review_lengths = [len(review) for review in list_of_texts]
maxlen = max(review_lengths)
print("Maximum length of sequences:", maxlen)
# Out:
# Maximum length of sequences: 37

# %%
# Based on above, maxlen of 75 should be plenty
maxlen = 75
tokenizer = Tokenizer()
tokenizer.fit_on_texts(labeled_data['processed_text'])  
sequences = tokenizer.texts_to_sequences(labeled_data['processed_text'])

word_index = tokenizer.word_index
vocab_size = len(word_index) + 1
embedding_dim = 50  

# Create embedding matrix
embedding_matrix = np.zeros((vocab_size, embedding_dim))
for word, i in word_index.items():
    embedding_vector = embeddings_dict.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# Pad sequences to ensure all sentences are ultimately stored as the same length
data = pad_sequences(sequences, maxlen=maxlen)

# %%
# 5 potential labels for classification
num_labels = 5

# %% [markdown]
# ### Recurrent Neural Network Model

# %%
# Standard LSTM (Long Short-Term Memory) model, inputs sequences processed from left to right
model = Sequential()
model.add(Embedding(input_dim=vocab_size,
                    output_dim=embedding_dim,
                    weights=[embedding_matrix],
                    #input_length=maxlen,
                    trainable=False))  
model.add(LSTM(128))
model.add(Dense(num_labels, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Extract the labels from the DataFrame
labels_columns = ['service', 'food', 'anecdotes/miscellaneous', 'price', 'ambience']
labels = labeled_data[labels_columns]

#Convert labels to a binary matrix
num_samples = len(labeled_data)
num_classes = len(labels_columns)
binary_labels = np.zeros((num_samples, num_classes))
for i, col in enumerate(labels_columns):
    binary_labels[:, i] = labeled_data[col]

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(data, binary_labels, test_size=0.3, random_state=42)

# %%
# Train model
model.fit(X_train, y_train, epochs=10, batch_size=100, validation_split=0.3)
# Out:
# Epoch 1/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 230ms/step - accuracy: 0.4016 - loss: 0.6235 - val_accuracy: 0.5910 - val_loss: 0.4687
# Epoch 2/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 203ms/step - accuracy: 0.5698 - loss: 0.4395 - val_accuracy: 0.6309 - val_loss: 0.3844
# Epoch 3/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 196ms/step - accuracy: 0.6158 - loss: 0.3844 - val_accuracy: 0.6521 - val_loss: 0.3546
# Epoch 4/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 195ms/step - accuracy: 0.6535 - loss: 0.3455 - val_accuracy: 0.6796 - val_loss: 0.3331
# Epoch 5/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 193ms/step - accuracy: 0.7158 - loss: 0.3097 - val_accuracy: 0.6908 - val_loss: 0.3278
# Epoch 6/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 193ms/step - accuracy: 0.7299 - loss: 0.2947 - val_accuracy: 0.7282 - val_loss: 0.3069
# Epoch 7/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 188ms/step - accuracy: 0.7319 - loss: 0.2734 - val_accuracy: 0.7382 - val_loss: 0.2969
# Epoch 8/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - accuracy: 0.7558 - loss: 0.2673 - val_accuracy: 0.7382 - val_loss: 0.2913
# Epoch 9/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 191ms/step - accuracy: 0.7424 - loss: 0.2665 - val_accuracy: 0.7394 - val_loss: 0.2941
# Epoch 10/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 192ms/step - accuracy: 0.7523 - loss: 0.2551 - val_accuracy: 0.7431 - val_loss: 0.2833

# %%
# Evaluate model

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.7359 - loss: 0.2908
# Test Loss: 0.2860836982727051
# Test Accuracy: 0.7338569164276123

# %% [markdown]
# ### Second Recurrent Neural Network Model

# %%
# Bidirectional LSTM model, processes both forward and backward

model = Sequential()
model.add(Embedding(input_dim=vocab_size,
                    output_dim=embedding_dim,
                    weights=[embedding_matrix],
                    #input_length=maxlen,
                    trainable=False))  
model.add(Bidirectional(LSTM(128, return_sequences=True)))  
model.add(Bidirectional(LSTM(64)))  
model.add(Dense(num_labels, activation='sigmoid'))  

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=10, batch_size=100, validation_split=0.3)

# Evaluate
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# Epoch 1/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 17s 454ms/step - accuracy: 0.3476 - loss: 0.5945 - val_accuracy: 0.5973 - val_loss: 0.4341
# Epoch 2/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 391ms/step - accuracy: 0.5829 - loss: 0.4062 - val_accuracy: 0.6297 - val_loss: 0.3790
# Epoch 3/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 397ms/step - accuracy: 0.6583 - loss: 0.3605 - val_accuracy: 0.6933 - val_loss: 0.3310
# Epoch 4/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 395ms/step - accuracy: 0.6998 - loss: 0.3120 - val_accuracy: 0.7244 - val_loss: 0.3191
# Epoch 5/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 420ms/step - accuracy: 0.7402 - loss: 0.2858 - val_accuracy: 0.7382 - val_loss: 0.2983
# Epoch 6/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 397ms/step - accuracy: 0.7428 - loss: 0.2805 - val_accuracy: 0.7244 - val_loss: 0.2944
# Epoch 7/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 374ms/step - accuracy: 0.7594 - loss: 0.2616 - val_accuracy: 0.7394 - val_loss: 0.2878
# Epoch 8/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 384ms/step - accuracy: 0.7669 - loss: 0.2455 - val_accuracy: 0.7357 - val_loss: 0.2830
# Epoch 9/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 391ms/step - accuracy: 0.7609 - loss: 0.2412 - val_accuracy: 0.7007 - val_loss: 0.3018
# Epoch 10/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 383ms/step - accuracy: 0.7580 - loss: 0.2393 - val_accuracy: 0.7182 - val_loss: 0.2940
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.7253 - loss: 0.2899
# Test Loss: 0.2854008972644806
# Test Accuracy: 0.7286213040351868

# %% [markdown]
# #### There's not much of a difference between the two models. Let's evaluate the performance within the different topics.

# %%
from sklearn.metrics import classification_report

# Get model predictions
y_pred = model.predict(X_test)

# Round the predictions to get binary values
y_pred_binary = (y_pred > 0.5).astype(int)

# Generate classification report
report = classification_report(y_test, y_pred_binary, target_names=labels_columns)
print(report)
# Out:
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step
#                          precision    recall  f1-score   support
#
#                 service       0.87      0.60      0.71       216
#                    food       0.89      0.80      0.84       489
# anecdotes/miscellaneous       0.78      0.77      0.78       394
#                   price       0.73      0.39      0.51       111
#                ambience       0.66      0.54      0.59       152
#
#               micro avg       0.82      0.70      0.75      1362
#               macro avg       0.78      0.62      0.69      1362
#            weighted avg       0.82      0.70      0.75      1362
#             samples avg       0.77      0.73      0.74      1362
# C:\Users\Caitl\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# #### Let's see how imbalanced the labeled dataset is

# %%
# Count the number of rows where service = 1
service_count = (labeled_data['service'] == 1).sum()

# Count the number of rows where food = 1
food_count = (labeled_data['food'] == 1).sum()

# Count the number of rows where anecdotes/miscellaneous = 1
anecdotes_count = (labeled_data['anecdotes/miscellaneous'] == 1).sum()

# Count the number of rows where price = 1
price_count = (labeled_data['price'] == 1).sum()

# Count the number of rows where ambience = 1
ambience_count = (labeled_data['ambience'] == 1).sum()

# Print the counts
print("Number of rows where service = 1:", service_count)
print("Number of rows where food = 1:", food_count)
print("Number of rows where anecdotes/miscellaneous = 1:", anecdotes_count)
print("Number of rows where price = 1:", price_count)
print("Number of rows where ambience = 1:", ambience_count)
# Out:
# Number of rows where service = 1: 746
# Number of rows where food = 1: 1600
# Number of rows where anecdotes/miscellaneous = 1: 1335
# Number of rows where price = 1: 359
# Number of rows where ambience = 1: 487

# %% [markdown]
# #### Not surprisingly, the quality of the F1 score follows the quantity of labeled data for each topic
# <br>
# <br>
# <br>

# %% [markdown]
# ## Phase 2: Apply Model to Yelp Restaurant Reviews and Understand Restaurant Performance by Topic
# ***
# #### Taking a subset of Restaurant Yelp Reviews that are in the 3 star range. This group is performing OK, but could use more information on how they can moderately improve to jump into the 4 star range.

# %% [markdown]
# ### Import Yelp Datasets, Filter, and Combine

# %%
# Load Yelp Review dataset
reviews = pd.read_json('yelp_academic_dataset_review.json', lines=True)
reviews
# Out:
#                       review_id                 user_id  \
# 0        KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 1        BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q
# 2        saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A
# 3        AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 4        Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ
# ...                         ...                     ...
# 6990275  H0RIamZu0B0Ei0P4aeh3sQ  qskILQ3k0I_qcCMI-k6_QQ
# 6990276  shTPgbgdwTHSuU67mGCmZQ  Zo0th2m8Ez4gLSbHftiQvg
# 6990277  YNfNhgZlaaCO5Q_YJR4rEw  mm6E4FbCMwJmb7kPDZ5v2Q
# 6990278  i-I4ZOhoX70Nw5H0FwrQUA  YwAMC-jvZ1fvEUum6QkEkw
# 6990279  RwcKOdEuLRHNJe4M9-qpqg  6JehEvdoCvZPJ_XIxnzIIw
#
#                     business_id  stars  useful  funny  cool  \
# 0        XQfwVwDr-v0ZS3_CbbE5Xw      3       0      0     0
# 1        7ATYjTIgM3jUlt4UM3IypQ      5       1      0     1
# 2        YjUWPpI6HXG530lwP-fb2A      3       0      0     0
# 3        kxX2SOes4o-D3ZQBkiMRfA      5       1      0     1
# 4        e4Vwtrqf-wpJfwesgvdgxQ      4       1      0     1
# ...                         ...    ...     ...    ...   ...
# 6990275  jals67o91gcrD4DC81Vk6w      5       1      2     1
# 6990276  2vLksaMmSEcGbjI5gywpZA      5       2      1     2
# 6990277  R1khUUxidqfaJmcpmGd4aw      4       1      0     0
# 6990278  Rr9kKArrMhSLVE9a53q-aA      5       1      0     0
# 6990279  VAeEXLbEcI9Emt9KGYq9aA      3      10      3     7
#
#                                                       text                date
# 0        If you decide to eat here, just be aware it is... 2018-07-07 22:09:11
# 1        I've taken a lot of spin classes over the year... 2012-01-03 15:28:18
# 2        Family diner. Had the buffet. Eclectic assortm... 2014-02-05 20:30:30
# 3        Wow!  Yummy, different,  delicious.   Our favo... 2015-01-04 00:01:03
# 4        Cute interior and owner (?) gave us tour of up... 2017-01-14 20:54:15
# ...                                                    ...                 ...
# 6990275  Latest addition to services from ICCU is Apple... 2014-12-17 21:45:20
# 6990276  This spot offers a great, affordable east week... 2021-03-31 16:55:10
# 6990277  This Home Depot won me over when I needed to g... 2019-12-30 03:56:30
# 6990278  For when I'm feeling like ignoring my calorie-... 2022-01-19 18:59:27
# 6990279  Located in the 'Walking District' in Nashville... 2018-01-02 22:50:47
#
# [6990280 rows x 9 columns]

# %%
# Load Yelp Business dataset
business = pd.read_json('yelp_academic_dataset_business.json', lines=True)
business
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1       87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2                  5255 E Broadway Blvd         Tucson    AZ       85711
# 3                           935 Race St   Philadelphia    PA       19107
# 4                         101 Walnut St     Green Lane    PA       18054
# ...                                 ...            ...   ...         ...
# 150341                3388 Gateway Blvd       Edmonton    AB     T6J 5H2
# 150342               2813 Bransford Ave      Nashville    TN       37204
# 150343           6020 E 82nd St, Ste 46   Indianapolis    IN       46250
# 150344                     2472 Troy Rd   Edwardsville    IL       62025
# 150345            238 Apollo Beach Blvd   Apollo beach    FL       33572
#
#          latitude   longitude  stars  review_count  is_open  \
# 0       34.426679 -119.711197    5.0             7        0
# 1       38.551126  -90.335695    3.0            15        1
# 2       32.223236 -110.880452    3.5            22        0
# 3       39.955505  -75.155564    4.0            80        1
# 4       40.338183  -75.471659    4.5            13        1
# ...           ...         ...    ...           ...      ...
# 150341  53.468419 -113.492054    3.0            13        1
# 150342  36.115118  -86.766925    4.0             5        1
# 150343  39.908707  -86.065088    3.5             8        1
# 150344  38.782351  -89.950558    4.0            24        1
# 150345  27.771002  -82.394910    4.5             9        1
#
#                                                attributes  \
# 0                           {'ByAppointmentOnly': 'True'}
# 1                  {'BusinessAcceptsCreditCards': 'True'}
# 2       {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 3       {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4       {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
# ...                                                   ...
# 150341  {'ByAppointmentOnly': 'False', 'RestaurantsPri...
# 150342  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 150343  {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 150344  {'BusinessParking': '{'garage': False, 'street...
# 150345  {'WheelchairAccessible': 'True', 'BusinessAcce...
#
#                                                categories  \
# 0       Doctors, Traditional Chinese Medicine, Naturop...
# 1       Shipping Centers, Local Services, Notaries, Ma...
# 2       Department Stores, Shopping, Fashion, Home & G...
# 3       Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                               Brewpubs, Breweries, Food
# ...                                                   ...
# 150341                         Nail Salons, Beauty & Spas
# 150342  Pets, Nurseries & Gardening, Pet Stores, Hobby...
# 150343  Shopping, Jewelry, Piercing, Toy Stores, Beaut...
# 150344  Fitness/Exercise Equipment, Eyewear & Optician...
# 150345  Beauty & Spas, Permanent Makeup, Piercing, Tattoo
#
#                                                     hours
# 0                                                    None
# 1       {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2       {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 3       {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4       {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...
# ...                                                   ...
# 150341  {'Monday': '10:0-19:30', 'Tuesday': '10:0-19:3...
# 150342  {'Monday': '9:30-17:30', 'Tuesday': '9:30-17:3...
# 150343                                               None
# 150344  {'Monday': '9:0-20:0', 'Tuesday': '9:0-20:0', ...
# 150345  {'Tuesday': '12:0-19:0', 'Wednesday': '12:0-19...
#
# [150346 rows x 14 columns]

# %%
# Drop N/As in Cateogry column and filter for Restaurants only
business.dropna(subset=['categories'], inplace=True) 
restaurants = business[business['categories'].str.contains('Restaurants', case=False)]
restaurants
# Out:
#                    business_id                           name  \
# 3       MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries
# 5       CF33F8-E6oudUQ46HnavjQ                 Sonic Drive-In
# 8       k0hlBqXX-Bt0vf1op7Jr1w          Tsevi's Pub And Grill
# 9       bBDDEgkFA1Otx9Lfe7BZUQ                 Sonic Drive-In
# 11      eEOYSgkmpB90uNA7lDOMRA          Vietnamese Food Truck
# ...                        ...                            ...
# 150325  l9eLGG9ZKpLJzboZq-9LRQ                           Wawa
# 150327  cM6V90ExQD6KMSU3rRB5ZA              Dutch Bros Coffee
# 150336  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
# 150339  2O2K6SXPWv56amqxCECd4w                   The Plum Pit
# 150340  hn9Toz3s-Ei3uZPt7esExA          West Side Kebab House
#
#                       address             city state postal_code   latitude  \
# 3                 935 Race St     Philadelphia    PA       19107  39.955505
# 5               615 S Main St     Ashland City    TN       37015  36.269593
# 8           8025 Mackenzie Rd           Affton    MO       63123  38.565165
# 9         2312 Dickerson Pike        Nashville    TN       37207  36.208102
# 11                                   Tampa Bay    FL       33602  27.955269
# ...                       ...              ...   ...         ...        ...
# 150325        19 N Bishop Ave  Clifton Heights    PA       19018  39.925656
# 150327    1181 N Milwaukee St            Boise    ID       83704  43.615401
# 150336          1108 S 9th St     Philadelphia    PA       19147  39.935982
# 150339        4405 Pennell Rd            Aston    DE       19014  39.856185
# 150340  2470 Guardian Road NW         Edmonton    AB     T5T 1K8  53.509649
#
#          longitude  stars  review_count  is_open  \
# 3       -75.155564    4.0            80        1
# 5       -87.058943    2.0             6        1
# 8       -90.321087    3.0            19        0
# 9       -86.768170    1.5            10        1
# 11      -82.456320    4.0            10        1
# ...            ...    ...           ...      ...
# 150325  -75.310344    3.0            11        1
# 150327 -116.284689    4.0            33        1
# 150336  -75.158665    4.5            35        1
# 150339  -75.427725    4.5            14        1
# 150340 -113.675999    4.5            18        0
#
#                                                attributes  \
# 3       {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 5       {'BusinessParking': 'None', 'BusinessAcceptsCr...
# 8       {'Caters': 'True', 'Alcohol': 'u'full_bar'', '...
# 9       {'RestaurantsAttire': ''casual'', 'Restaurants...
# 11      {'Alcohol': ''none'', 'OutdoorSeating': 'None'...
# ...                                                   ...
# 150325  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 150327  {'WiFi': ''free'', 'RestaurantsGoodForGroups':...
# 150336  {'WheelchairAccessible': 'False', 'Restaurants...
# 150339  {'RestaurantsDelivery': 'False', 'BusinessAcce...
# 150340  {'Ambience': '{'touristy': False, 'hipster': F...
#
#                                                categories  \
# 3       Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 5       Burgers, Fast Food, Sandwiches, Food, Ice Crea...
# 8       Pubs, Restaurants, Italian, Bars, American (Tr...
# 9       Ice Cream & Frozen Yogurt, Fast Food, Burgers,...
# 11             Vietnamese, Food, Restaurants, Food Trucks
# ...                                                   ...
# 150325  Restaurants, Sandwiches, Convenience Stores, C...
# 150327  Cafes, Juice Bars & Smoothies, Coffee & Tea, R...
# 150336                               Restaurants, Mexican
# 150339  Restaurants, Comfort Food, Food, Food Trucks, ...
# 150340                        Middle Eastern, Restaurants
#
#                                                     hours
# 3       {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 5       {'Monday': '0:0-0:0', 'Tuesday': '6:0-22:0', '...
# 8                                                    None
# 9       {'Monday': '0:0-0:0', 'Tuesday': '6:0-21:0', '...
# 11      {'Monday': '11:0-14:0', 'Tuesday': '11:0-14:0'...
# ...                                                   ...
# 150325  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 150327  {'Monday': '0:0-0:0', 'Tuesday': '0:0-17:0', '...
# 150336  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 150339  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 150340  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
#
# [52268 rows x 14 columns]

# %%
# Narrow down list to businesses where there's room for minor improvements
restaurants = restaurants[(restaurants['stars'] >= 3) & (restaurants['stars'] <= 4)]
restaurants
# Out:
#                    business_id                            name  \
# 3       MTSW4McQd7CbVtyjqoe9mw              St Honore Pastries
# 8       k0hlBqXX-Bt0vf1op7Jr1w           Tsevi's Pub And Grill
# 11      eEOYSgkmpB90uNA7lDOMRA           Vietnamese Food Truck
# 15      MUTTqe8uqyMdBl186RmNeA                        Tuna Bar
# 20      WKMJwqnfZKsAae75RMP6jA  Roast Coffeehouse and Wine Bar
# ...                        ...                             ...
# 150313  sf_oQ62L8UEnOOLf00nNGA                       Pizza Hut
# 150319  8n93L-ilMAsvwUatarykSg                     Kitchen Gia
# 150322  2MAQeAqmD8enCT2ZYqUgIQ     The Melting Pot - Nashville
# 150325  l9eLGG9ZKpLJzboZq-9LRQ                            Wawa
# 150327  cM6V90ExQD6KMSU3rRB5ZA               Dutch Bros Coffee
#
#                      address             city state postal_code   latitude  \
# 3                935 Race St     Philadelphia    PA       19107  39.955505
# 8          8025 Mackenzie Rd           Affton    MO       63123  38.565165
# 11                                  Tampa Bay    FL       33602  27.955269
# 15               205 Race St     Philadelphia    PA       19106  39.953949
# 20       10359 104 Street NW         Edmonton    AB     T5J 1B9  53.546045
# ...                      ...              ...   ...         ...        ...
# 150313      5028 Old Hickory        Hermitage    TN       37076  36.193201
# 150319        3716 Spruce St     Philadelphia    PA       19104  39.951018
# 150322  166 2nd Ave N, Ste A        Nashville    TN       37201  36.163875
# 150325       19 N Bishop Ave  Clifton Heights    PA       19018  39.925656
# 150327   1181 N Milwaukee St            Boise    ID       83704  43.615401
#
#          longitude  stars  review_count  is_open  \
# 3       -75.155564    4.0            80        1
# 8       -90.321087    3.0            19        0
# 11      -82.456320    4.0            10        1
# 15      -75.143226    4.0           245        1
# 20     -113.499169    4.0            40        0
# ...            ...    ...           ...      ...
# 150313  -86.614748    3.0             6        1
# 150319  -75.198240    3.0            22        0
# 150322  -86.776311    4.0           204        0
# 150325  -75.310344    3.0            11        1
# 150327 -116.284689    4.0            33        1
#
#                                                attributes  \
# 3       {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 8       {'Caters': 'True', 'Alcohol': 'u'full_bar'', '...
# 11      {'Alcohol': ''none'', 'OutdoorSeating': 'None'...
# 15      {'RestaurantsReservations': 'True', 'Restauran...
# 20      {'OutdoorSeating': 'False', 'Caters': 'True', ...
# ...                                                   ...
# 150313  {'RestaurantsTakeOut': 'True', 'GoodForKids': ...
# 150319  {'RestaurantsGoodForGroups': 'True', 'BikePark...
# 150322  {'RestaurantsDelivery': 'False', 'RestaurantsR...
# 150325  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 150327  {'WiFi': ''free'', 'RestaurantsGoodForGroups':...
#
#                                                categories  \
# 3       Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 8       Pubs, Restaurants, Italian, Bars, American (Tr...
# 11             Vietnamese, Food, Restaurants, Food Trucks
# 15                      Sushi Bars, Restaurants, Japanese
# 20      Coffee & Tea, Food, Cafes, Bars, Wine Bars, Re...
# ...                                                   ...
# 150313  Restaurants, Pizza, Fast Food, Chicken Wings, ...
# 150319  Coffee & Tea, Food, Sandwiches, American (Trad...
# 150322    Fondue, Beer, Wine & Spirits, Food, Restaurants
# 150325  Restaurants, Sandwiches, Convenience Stores, C...
# 150327  Cafes, Juice Bars & Smoothies, Coffee & Tea, R...
#
#                                                     hours
# 3       {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 8                                                    None
# 11      {'Monday': '11:0-14:0', 'Tuesday': '11:0-14:0'...
# 15      {'Tuesday': '13:30-22:0', 'Wednesday': '13:30-...
# 20      {'Monday': '8:0-18:0', 'Tuesday': '8:0-18:0', ...
# ...                                                   ...
# 150313  {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...
# 150319  {'Monday': '9:0-19:30', 'Tuesday': '9:0-19:30'...
# 150322  {'Monday': '0:0-0:0', 'Tuesday': '16:0-21:0', ...
# 150325  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 150327  {'Monday': '0:0-0:0', 'Tuesday': '0:0-17:0', '...
#
# [32871 rows x 14 columns]

# %%
# Narrow down list to businesses with a minimum of 80 reviews so there's datapoints
restaurants = restaurants[restaurants['review_count'] >= 80]
restaurants
# Out:
#                    business_id                                 name  \
# 3       MTSW4McQd7CbVtyjqoe9mw                   St Honore Pastries
# 15      MUTTqe8uqyMdBl186RmNeA                             Tuna Bar
# 27      tMkwHmWFUEXrC9ZduonpTg                   The Green Pheasant
# 33      kV_Q1oqis8Qli8dUoGpTyQ                        Ardmore Pizza
# 41      ljxNT9p0y7YMPx0fcNBGig  Tony's Restaurant & 3rd Street Cafe
# ...                        ...                                  ...
# 150254  Ld3qgGua7MqrFnZY8AIo0A                         Café Ventana
# 150260  N8fK2E6YNyo04DbVNvgIQw                   Sage Mediterranean
# 150275  IeSD0nMKRFYUTnR5nZH1CQ                      HighWire Lounge
# 150290  uriD7RFuHhLJeDdKaf0nFA                           Pizza Guru
# 150322  2MAQeAqmD8enCT2ZYqUgIQ          The Melting Pot - Nashville
#
#                      address           city state postal_code   latitude  \
# 3                935 Race St   Philadelphia    PA       19107  39.955505
# 15               205 Race St   Philadelphia    PA       19106  39.953949
# 27             215 1st Ave S      Nashville    TN       37201  36.159886
# 33         10 Rittenhouse Pl        Ardmore    PA       19003  40.006707
# 41              312 Piasa St          Alton    IL       62002  38.896563
# ...                      ...            ...   ...         ...        ...
# 150254      3919 W Pine Blvd    Saint Louis    MO       63108  38.638030
# 150260         150 Bridge St   Phoenixville    PA       19460  40.134042
# 150275      14 S Arizona Ave         Tucson    AZ       85701  32.221828
# 150290         3534 State St  Santa Barbara    CA       93105  34.440689
# 150322  166 2nd Ave N, Ste A      Nashville    TN       37201  36.163875
#
#          longitude  stars  review_count  is_open  \
# 3       -75.155564    4.0            80        1
# 15      -75.143226    4.0           245        1
# 27      -86.773197    4.0           161        0
# 33      -75.289671    3.5           109        1
# 41      -90.186203    3.0            94        1
# ...            ...    ...           ...      ...
# 150254  -90.242133    3.5           290        0
# 150260  -75.514528    4.0           118        1
# 150275 -110.967969    3.5           111        1
# 150290 -119.739681    4.0           299        0
# 150322  -86.776311    4.0           204        0
#
#                                                attributes  \
# 3       {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 15      {'RestaurantsReservations': 'True', 'Restauran...
# 27      {'RestaurantsGoodForGroups': 'True', 'HappyHou...
# 33      {'RestaurantsGoodForGroups': 'True', 'WiFi': '...
# 41      {'RestaurantsReservations': 'True', 'Restauran...
# ...                                                   ...
# 150254  {'RestaurantsGoodForGroups': 'True', 'Alcohol'...
# 150260  {'WiFi': ''no'', 'RestaurantsAttire': ''casual...
# 150275  {'BusinessParking': '{'garage': False, 'street...
# 150290  {'NoiseLevel': 'u'average'', 'RestaurantsGoodF...
# 150322  {'RestaurantsDelivery': 'False', 'RestaurantsR...
#
#                                                categories  \
# 3       Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 15                      Sushi Bars, Restaurants, Japanese
# 27                         Restaurants, Japanese, Seafood
# 33                                     Pizza, Restaurants
# 41      Restaurants, Specialty Food, Steakhouses, Food...
# ...                                                   ...
# 150254  Food, Breakfast & Brunch, Cajun/Creole, Restau...
# 150260                         Restaurants, Mediterranean
# 150275  Bars, Tapas Bars, Restaurants, Nightlife, Gast...
# 150290                           Restaurants, Pizza, Food
# 150322    Fondue, Beer, Wine & Spirits, Food, Restaurants
#
#                                                     hours
# 3       {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 15      {'Tuesday': '13:30-22:0', 'Wednesday': '13:30-...
# 27      {'Wednesday': '16:0-22:0', 'Thursday': '16:0-2...
# 33      {'Monday': '11:0-0:0', 'Tuesday': '11:0-0:0', ...
# 41      {'Monday': '0:0-0:0', 'Tuesday': '16:0-21:30',...
# ...                                                   ...
# 150254  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 150260  {'Tuesday': '11:30-22:30', 'Wednesday': '11:30...
# 150275  {'Tuesday': '17:0-2:0', 'Wednesday': '17:0-2:0...
# 150290  {'Monday': '15:0-21:0', 'Tuesday': '15:0-21:0'...
# 150322  {'Monday': '0:0-0:0', 'Tuesday': '16:0-21:0', ...
#
# [10552 rows x 14 columns]

# %%
# Merge restaraunt dataframe with reviews dataframe
mid_rest_reviews = pd.merge(reviews, restaurants, on='business_id', how='inner')
mid_rest_reviews
# Out:
#                       review_id                 user_id  \
# 0        KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 1        VJxlBnJmCDIy8DFG0kjSow  Iaee7y6zdSB3B-kRCo4z1w
# 2        S6pQZQocMB1WHMjTRbt77A  ejFxLGqQcWNLdNByJlIhnQ
# 3        WqgTKVqWVHDHjnjEsBvUgg  f7xa0p_1V9lx53iIGN5Sug
# 4        M0wzFFb7pefOPcxeRVbLag  dCooFVCk8M1nVaQqcfTL3Q
# ...                         ...                     ...
# 2673092  rbPKXUuCEohjKLfLP_4CVg  -6bsEIMFz6ndaWXaakISSw
# 2673093  yvZTL0ffB7B5KIbn_CTURw  sGgJvAky5QSKI26bqUAqxQ
# 2673094  -O5_SIS43vIta6ZcZe8nNA  swpVVjVkQU5FmpPuueOAzA
# 2673095  mJHxrN38MxEW910nhNupzg  uqhRApncBooRxJ0dVadS3w
# 2673096  1ryZLb9pSBz0y66tHB-rfw  XJTO9x78TgWE94cmXqNduA
#
#                     business_id  stars_x  useful  funny  cool  \
# 0        XQfwVwDr-v0ZS3_CbbE5Xw        3       0      0     0
# 1        XQfwVwDr-v0ZS3_CbbE5Xw        2       0      0     0
# 2        XQfwVwDr-v0ZS3_CbbE5Xw        4       2      0     1
# 3        XQfwVwDr-v0ZS3_CbbE5Xw        3       0      0     0
# 4        XQfwVwDr-v0ZS3_CbbE5Xw        2       0      0     0
# ...                         ...      ...     ...    ...   ...
# 2673092  c3QxX3toWdqJnKQmmIliRQ        5       4      1     3
# 2673093  c3QxX3toWdqJnKQmmIliRQ        4       0      0     0
# 2673094  c3QxX3toWdqJnKQmmIliRQ        4       0      0     0
# 2673095  c3QxX3toWdqJnKQmmIliRQ        4       5      1     1
# 2673096  c3QxX3toWdqJnKQmmIliRQ        1       1      2     0
#
#                                                       text  \
# 0        If you decide to eat here, just be aware it is...
# 1        This is the second time we tried turning point...
# 2        The place is cute and the staff was very frien...
# 3        We came on a Saturday morning after waiting a ...
# 4        Mediocre at best. The decor is very nice, and ...
# ...                                                    ...
# 2673092  ITS BRINGING SEXY BACK. New bar, 5th and Broad...
# 2673093  Live music, great food, and excellent service(...
# 2673094  Very nice, large and airy restaurant right in ...
# 2673095  The food and drinks were good! I ordered the p...
# 2673096  The supper club is ridiculously expensive. So,...
#
#                        date                                 name  ... state  \
# 0       2018-07-07 22:09:11         Turning Point of North Wales  ...    PA
# 1       2017-05-13 17:06:55         Turning Point of North Wales  ...    PA
# 2       2017-08-08 00:58:18         Turning Point of North Wales  ...    PA
# 3       2017-11-19 02:20:23         Turning Point of North Wales  ...    PA
# 4       2017-09-09 17:49:47         Turning Point of North Wales  ...    PA
# ...                     ...                                  ...  ...   ...
# 2673092 2021-04-27 22:20:51  Honky Tonk - The Twelve Thirty Club  ...    TN
# 2673093 2021-08-06 14:25:56  Honky Tonk - The Twelve Thirty Club  ...    TN
# 2673094 2021-09-24 14:33:49  Honky Tonk - The Twelve Thirty Club  ...    TN
# 2673095 2021-04-22 13:49:47  Honky Tonk - The Twelve Thirty Club  ...    TN
# 2673096 2021-11-29 18:26:40  Honky Tonk - The Twelve Thirty Club  ...    TN
#
#         postal_code   latitude  longitude  stars_y  review_count  is_open  \
# 0             19454  40.210196 -75.223639      3.0           169        1
# 1             19454  40.210196 -75.223639      3.0           169        1
# 2             19454  40.210196 -75.223639      3.0           169        1
# 3             19454  40.210196 -75.223639      3.0           169        1
# 4             19454  40.210196 -75.223639      3.0           169        1
# ...             ...        ...        ...      ...           ...      ...
# 2673092       37203  36.160630 -86.778829      4.0           110        1
# 2673093       37203  36.160630 -86.778829      4.0           110        1
# 2673094       37203  36.160630 -86.778829      4.0           110        1
# 2673095       37203  36.160630 -86.778829      4.0           110        1
# 2673096       37203  36.160630 -86.778829      4.0           110        1
#
#                                                 attributes  \
# 0        {'NoiseLevel': 'u'average'', 'HasTV': 'False',...
# 1        {'NoiseLevel': 'u'average'', 'HasTV': 'False',...
# 2        {'NoiseLevel': 'u'average'', 'HasTV': 'False',...
# 3        {'NoiseLevel': 'u'average'', 'HasTV': 'False',...
# 4        {'NoiseLevel': 'u'average'', 'HasTV': 'False',...
# ...                                                    ...
# 2673092  {'HasTV': 'True', 'OutdoorSeating': 'True', 'R...
# 2673093  {'HasTV': 'True', 'OutdoorSeating': 'True', 'R...
# 2673094  {'HasTV': 'True', 'OutdoorSeating': 'True', 'R...
# 2673095  {'HasTV': 'True', 'OutdoorSeating': 'True', 'R...
# 2673096  {'HasTV': 'True', 'OutdoorSeating': 'True', 'R...
#
#                                                 categories  \
# 0        Restaurants, Breakfast & Brunch, Food, Juice B...
# 1        Restaurants, Breakfast & Brunch, Food, Juice B...
# 2        Restaurants, Breakfast & Brunch, Food, Juice B...
# 3        Restaurants, Breakfast & Brunch, Food, Juice B...
# 4        Restaurants, Breakfast & Brunch, Food, Juice B...
# ...                                                    ...
# 2673092  American (Traditional), Restaurants, Cocktail ...
# 2673093  American (Traditional), Restaurants, Cocktail ...
# 2673094  American (Traditional), Restaurants, Cocktail ...
# 2673095  American (Traditional), Restaurants, Cocktail ...
# 2673096  American (Traditional), Restaurants, Cocktail ...
#
#                                                      hours
# 0        {'Monday': '7:30-15:0', 'Tuesday': '7:30-15:0'...
# 1        {'Monday': '7:30-15:0', 'Tuesday': '7:30-15:0'...
# 2        {'Monday': '7:30-15:0', 'Tuesday': '7:30-15:0'...
# 3        {'Monday': '7:30-15:0', 'Tuesday': '7:30-15:0'...
# 4        {'Monday': '7:30-15:0', 'Tuesday': '7:30-15:0'...
# ...                                                    ...
# 2673092  {'Monday': '0:0-0:0', 'Tuesday': '11:0-0:0', '...
# 2673093  {'Monday': '0:0-0:0', 'Tuesday': '11:0-0:0', '...
# 2673094  {'Monday': '0:0-0:0', 'Tuesday': '11:0-0:0', '...
# 2673095  {'Monday': '0:0-0:0', 'Tuesday': '11:0-0:0', '...
# 2673096  {'Monday': '0:0-0:0', 'Tuesday': '11:0-0:0', '...
#
# [2673097 rows x 22 columns]

# %%
# Simplify dataframe
mid_rest_reviews.rename(columns={'stars_x': 'review_stars'}, inplace=True)
mid_rest_reviews.rename(columns={'stars_y': 'overall_stars'}, inplace=True)

desired_order = ['business_id', 'overall_stars', 'text', 'review_stars']  
mid_rest_reviews = mid_rest_reviews[desired_order]  
mid_rest_reviews
# Out:
#                     business_id  overall_stars  \
# 0        XQfwVwDr-v0ZS3_CbbE5Xw            3.0
# 1        XQfwVwDr-v0ZS3_CbbE5Xw            3.0
# 2        XQfwVwDr-v0ZS3_CbbE5Xw            3.0
# 3        XQfwVwDr-v0ZS3_CbbE5Xw            3.0
# 4        XQfwVwDr-v0ZS3_CbbE5Xw            3.0
# ...                         ...            ...
# 2673092  c3QxX3toWdqJnKQmmIliRQ            4.0
# 2673093  c3QxX3toWdqJnKQmmIliRQ            4.0
# 2673094  c3QxX3toWdqJnKQmmIliRQ            4.0
# 2673095  c3QxX3toWdqJnKQmmIliRQ            4.0
# 2673096  c3QxX3toWdqJnKQmmIliRQ            4.0
#
#                                                       text  review_stars
# 0        If you decide to eat here, just be aware it is...             3
# 1        This is the second time we tried turning point...             2
# 2        The place is cute and the staff was very frien...             4
# 3        We came on a Saturday morning after waiting a ...             3
# 4        Mediocre at best. The decor is very nice, and ...             2
# ...                                                    ...           ...
# 2673092  ITS BRINGING SEXY BACK. New bar, 5th and Broad...             5
# 2673093  Live music, great food, and excellent service(...             4
# 2673094  Very nice, large and airy restaurant right in ...             4
# 2673095  The food and drinks were good! I ordered the p...             4
# 2673096  The supper club is ridiculously expensive. So,...             1
#
# [2673097 rows x 4 columns]

# %% [markdown]
# ### Pick random restaurant to test on as proof of concept

# %%
# Get a unique list of business_ids
unique_business_ids = mid_rest_reviews['business_id'].unique()

# Set the random seed to a fixed value for repeatability
np.random.seed(42)

# Pick one business_id at random
random_business_id = np.random.choice(unique_business_ids)

# Filter the dataframe to get all reviews for the randomly chosen business_id
selected_business = mid_rest_reviews[mid_rest_reviews['business_id'] == random_business_id]

# Expand to see full text
pd.set_option('display.max_colwidth', None)
selected_business
# Out:
#                     business_id  overall_stars  \
# 1839941  grBPIq_eJCT_SGuhvMrUZQ            3.5
# 1839942  grBPIq_eJCT_SGuhvMrUZQ            3.5
# 1839943  grBPIq_eJCT_SGuhvMrUZQ            3.5
# 1839944  grBPIq_eJCT_SGuhvMrUZQ            3.5
# 1839945  grBPIq_eJCT_SGuhvMrUZQ            3.5
# ...                         ...            ...
# 1840087  grBPIq_eJCT_SGuhvMrUZQ            3.5
# 1840088  grBPIq_eJCT_SGuhvMrUZQ            3.5
# 1840089  grBPIq_eJCT_SGuhvMrUZQ            3.5
# 1840090  grBPIq_eJCT_SGuhvMrUZQ            3.5
# 1840091  grBPIq_eJCT_SGuhvMrUZQ            3.5
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         text  \
# 1839941                             Decent place to come grab pizza. Crust was a little underdone on mine, but then again, I came on the busiest day of the year.\n\nI did a build your own pizza with the following:\n\nSauce: Red Sauce\nCheese: Shredded mozzarella with feta sprinkled around\nMeat: Smoked Ham, Bacon bits, Pepperoni\nVeggies: Red pepper, roasted garlic, basil, mushrooms\n\nThere really wasn't much to complain about on the pizza, but at the same time, nothing that made you take a step back and go "wow, that was amazing."\n\nI stopped by last night with a friend to take advantage of their Pi Day deal. At $3.14 a pizza, it was a steal, but then again, not every day is pie day. Decent pizza, and it's nice that you can customize it completely without spending a fortune. Just nothing outstanding.\n\nI just got this vibe that they minimize their ingredients. Thinnest layer of sauce I've seen on a pizza, 5 leaves of basil used when I asked for it as a topping, etc. \n\nIMHO, better than pieology by a lot, but there are other places I'd rather go. An A-OK from me.
# 1839942                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               This place is amazing. I love that you can make your own pizza the way you want. The girl at the register, Tatiana, was so friendly. The restaurant was clean as well.
# 1839943                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   This location is great! Only opened for about a month but service was fast and friendly. I love me some personalized pizza and sometimes franchise establishments become jaded, but this one is wonderful. So close to my house which means it's so dangerous! Plenty of parking in the 5 points plaza.\n\nMake sure to get the pesto drizzle at the end ;)\n\n- J
# 1839944                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   They get an instant review from me. This is a build your own pizza kind of place although they have some default menu. The service was quick and the staff was attentive! Easy 4 star. Keep it up!
# 1839945                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       This is a great place to stop in and get a quick, hardy pizza and salad. There isn't anything else on the menu and the air conditioning is too cold for our liking, but they have really tasty pizza and salads served up quick. We are definitely returning here because they also have gluten-free pizza crust available and daiya cheese alternative for my lactose and gluten free children. We are happy!
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# 1840087                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Loooove coming here! I get the allergy GF crust build your own pizza. The staff is really nice & they are pretty fast at cooking your pizza. I checked their ingredients online for the sauce & crust- no additives!
# 1840088                                                                                     Had a BOGO coupon, figured it couldn't hurt to try it out... most impressed at the new State Steet location! Staff was super friendly and we're very good at guiding you through the process of choosing a ton of different toppings/add ons. Got the Green Stripe and Art Lover... you can add any additional toppings with no extra charge, you can also add to their already listed signature pizzas. The line moved very quickly. It cooked so fast, it was hot and very flavorful. Very delish! To go boxes are ready on a shelf if neeed, a ton of Parm, red peppers and basil shakers available. The selection of lemonades looked great! Seating is a little cramped and has a weird layout and they should add one more trash receptacle towards the back, so people could have easier access. Customer service was def 2 up, we were checked in on twice. Would definitely go back. For a personal pizza for $8.25, you can't go wrong! Convenient, good parking, good price, filling and tasty, definitely recommend.
# 1840089                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Customize your pizza for only $9.00\nQuick, simple, good. \nEverything is very fresh and there are a lot of topping options, though none of them are organic. \nIt is the best affordable option in this area of SB.
# 1840090  First off, there's like 13 kids working and doing absolutely nothing. Literally running into each other laughing and joking. I got to the counter and ordered my pizza I asked the kid if the cauliflower crust was any good, he said "dude I don't know ...some people like it"\nIt Would  be wise for blaze Pizza to have their employees at least try some of their menu options so they can give positive or negative feedback to the customer, It would help the customer with his or her choices.\nI ordered the veg out... Big mistake! There's literally three vegetables on it Gorgonzola and a ton of marinara!! The combination of broccoli, Gorgonzola and red onion taste like fart! I was very disappointed because I have had this pizza before at a Blaze in Los Angeles and it was choice! This kid piled it on like he was at Subway sandwich! Lol!!! Why do you have so many employees? Sorry for the bad review i'm only trying to help!!\nThe kid at the register  was totally cool. He was polite and intelligent I don't know his name wish I did because you guys should make him manager!!
# 1840091                                                                                                                                                                                                                                                                                                                                                                                                                                                                               I won a free pizza through Instagram! This place is set up like an assembly line with all the toppings and sauces behind a glass wall you choose from. You get to select everything....crust, sauce, toppings. This is great! They were busy when I walked in to make my order of four pizzas-all different crusts & toppings and their work pace didn't stop, the employees flow so well... the order was made so quickly even tho it was busy, so impressed. They have a giant pizza oven that fits several pizzas. You can get sides like jalapeno and ranch. I enjoyed the pizzas I ordered and the service was friendly and fast.
#
#          review_stars
# 1839941             3
# 1839942             5
# 1839943             5
# 1839944             4
# 1839945             4
# ...               ...
# 1840087             5
# 1840088             5
# 1840089             3
# 1840090             1
# 1840091             5
#
# [151 rows x 4 columns]

# %% [markdown]
# ### Apply training model on each text segment of a review
# ***
# #### A review can cover multiple topics in one review, or even multiple topics in one sentence, such as "Food was great, but service was terrible". Therefore, the model needs to be applied on each segment instead of the reviews as a whole or sentences as a whole.

# %%
# List of punctuation marks to divide text segments on
punctuation_marks = [",", ".", "?", "!", ";"]

# %%
def custom_tokenize(text):
    # Manually tokenize the text to separate punctuation
    tokens = []
    current_word = ""
    for char in text:
        if char in string.punctuation:
            if current_word:
                tokens.append(current_word)
                current_word = ""
            tokens.append(char)  # Add the punctuation as a separate token
        elif char.isspace():
            if current_word:
                tokens.append(current_word)
                current_word = ""
        else:
            current_word += char
    if current_word:
        tokens.append(current_word)  # Add the last word if exists
    return tokens

# Apply the custom tokenize function
tokenized_texts = [custom_tokenize(text) for text in selected_business['text']]

# Initialize Tokenizer without filtering out any punctuation
tokenizer = Tokenizer(filters='')  # No filters to retain punctuation

# Fit tokenizer on the tokenized texts
tokenizer.fit_on_texts(tokenized_texts)

# Initialize an empty list to store all predictions
all_predictions = []

# Iterate through each tokenized text
for tokenized_text in tokenized_texts:
    # Initialize lists to store segment texts and their corresponding predictions
    segment_texts = []
    segment_predictions = []
    
    # Initialize variables to store the current segment text and its punctuation mark
    current_segment = ""
    current_punctuation = None
    
    # Iterate through each token in the tokenized text
    for token in tokenized_text:
        # If the token is a punctuation mark
        if token in punctuation_marks:
            # Check if the current segment is not empty
            if current_segment:
                # Append the current segment text and make prediction for it
                segment_texts.append(current_segment.strip())
                segment_predictions.append(model.predict(pad_sequences(tokenizer.texts_to_sequences([current_segment]), maxlen=maxlen))[0])
            
            # Update the current punctuation mark and reset the current segment
            current_punctuation = token
            current_segment = ""
        else:
            # Append the token to the current segment text
            current_segment += token + " "
    
    # Append the last segment text and make prediction for it
    if current_segment:
        segment_texts.append(current_segment.strip())
        segment_predictions.append(model.predict(pad_sequences(tokenizer.texts_to_sequences([current_segment]), maxlen=maxlen))[0])
    
    # Append the segment predictions to the list of all predictions
    all_predictions.append((segment_texts, segment_predictions))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step

# %%
# Check
all_predictions
# Out:
# [(['Decent place to come grab pizza',
#    'Crust was a little underdone on mine',
#    'but then again',
#    'I came on the busiest day of the year',
#    'I did a build your own pizza with the following : Sauce : Red Sauce Cheese : Shredded mozzarella with feta sprinkled around Meat : Smoked Ham',
#    'Bacon bits',
#    'Pepperoni Veggies : Red pepper',
#    'roasted garlic',
#    'basil',
#    "mushrooms There really wasn ' t much to complain about on the pizza",
#    'but at the same time',
#    'nothing that made you take a step back and go " wow',
#    'that was amazing',
#    '" I stopped by last night with a friend to take advantage of their Pi Day deal',
#    'At $ 3',
#    '14 a pizza',
#    'it was a steal',
#    'but then again',
#    'not every day is pie day',
#    'Decent pizza',
#    "and it ' s nice that you can customize it completely without spending a fortune",
#    'Just nothing outstanding',
#    'I just got this vibe that they minimize their ingredients',
#    "Thinnest layer of sauce I ' ve seen on a pizza",
#    '5 leaves of basil used when I asked for it as a topping',
#    'etc',
#    'IMHO',
#    'better than pieology by a lot',
#    "but there are other places I ' d rather go",
#    'An A - OK from me'],
#   [array([0.00644005, 0.04409686, 0.72142875, 0.01322344, 0.23210348],
#          dtype=float32),
#    array([0.03641776, 0.42165878, 0.21857697, 0.8517206 , 0.06037335],
#          dtype=float32),
#    array([0.04024317, 0.84218085, 0.08468569, 0.12145922, 0.00679521],
#          dtype=float32),
#    array([0.93198   , 0.2063656 , 0.06665043, 0.01734908, 0.23128386],
#          dtype=float32),
#    array([0.9373048 , 0.8152555 , 0.01207613, 0.02800487, 0.07146236],
#          dtype=float32),
#    array([0.05103858, 0.9093096 , 0.07500283, 0.03291868, 0.01242105],
#          dtype=float32),
#    array([0.2222669 , 0.75906515, 0.07973517, 0.03293015, 0.01345181],
#          dtype=float32),
#    array([0.03568552, 0.00681052, 0.85516423, 0.00418519, 0.05276816],
#          dtype=float32),
#    array([0.10886478, 0.04843969, 0.68997335, 0.01871722, 0.01769045],
#          dtype=float32),
#    array([0.57544416, 0.9083998 , 0.0781146 , 0.0644073 , 0.02086749],
#          dtype=float32),
#    array([0.51057196, 0.3331939 , 0.16892803, 0.04778338, 0.02267683],
#          dtype=float32),
#    array([0.01188434, 0.5001906 , 0.4499382 , 0.03471302, 0.16483662],
#          dtype=float32),
#    array([0.0427242 , 0.7622554 , 0.09398477, 0.32627225, 0.00690224],
#          dtype=float32),
#    array([0.97777593, 0.07851411, 0.05733625, 0.01559104, 0.10729309],
#          dtype=float32),
#    array([0.02330319, 0.01115566, 0.9230467 , 0.00824075, 0.0092107 ],
#          dtype=float32),
#    array([0.24810575, 0.03263402, 0.7056296 , 0.01774604, 0.00775383],
#          dtype=float32),
#    array([0.01520488, 0.04384273, 0.7407862 , 0.3086975 , 0.02130013],
#          dtype=float32),
#    array([0.04024317, 0.84218085, 0.08468569, 0.12145922, 0.00679521],
#          dtype=float32),
#    array([0.20935462, 0.35407385, 0.4189784 , 0.0126595 , 0.00543912],
#          dtype=float32),
#    array([0.02729633, 0.04265473, 0.6065103 , 0.01753565, 0.20947158],
#          dtype=float32),
#    array([0.05099208, 0.5954406 , 0.23222591, 0.02545135, 0.530734  ],
#          dtype=float32),
#    array([0.07993504, 0.7488601 , 0.16645706, 0.04376746, 0.00454761],
#          dtype=float32),
#    array([0.92798835, 0.8184204 , 0.01270557, 0.10962205, 0.09226026],
#          dtype=float32),
#    array([0.8122512 , 0.28856403, 0.17245275, 0.04388442, 0.02950841],
#          dtype=float32),
#    array([0.61501056, 0.03764459, 0.07066838, 0.01428436, 0.90847397],
#          dtype=float32),
#    array([0.16484913, 0.03111668, 0.7505402 , 0.02492552, 0.00540883],
#          dtype=float32),
#    array([0.05791735, 0.02407902, 0.8982805 , 0.00998481, 0.00479875],
#          dtype=float32),
#    array([0.02984794, 0.03459554, 0.7072695 , 0.11529995, 0.05792163],
#          dtype=float32),
#    array([0.88559973, 0.79563874, 0.05702376, 0.07525659, 0.04131782],
#          dtype=float32),
#    array([0.0182524 , 0.93068016, 0.12692703, 0.04604831, 0.01004762],
#          dtype=float32)]),
#  (['This place is amazing',
#    'I love that you can make your own pizza the way you want',
#    'The girl at the register',
#    'Tatiana',
#    'was so friendly',
#    'The restaurant was clean as well'],
#   [array([0.08140424, 0.9166995 , 0.04978044, 0.01577747, 0.00593866],
#          dtype=float32),
#    array([0.9740265 , 0.1107474 , 0.05772175, 0.01259532, 0.2519801 ],
#          dtype=float32),
#    array([0.01165973, 0.90103155, 0.15876465, 0.01885925, 0.01975668],
#          dtype=float32),
#    array([0.02933728, 0.01442601, 0.88636935, 0.0051749 , 0.01990527],
#          dtype=float32),
#    array([0.58356893, 0.06954943, 0.30695572, 0.18619604, 0.01912088],
#          dtype=float32),
#    array([0.04521259, 0.02334644, 0.14922507, 0.11341139, 0.9187676 ],
#          dtype=float32)]),
#  (['This location is great',
#    'Only opened for about a month but service was fast and friendly',
#    'I love me some personalized pizza and sometimes franchise establishments become jaded',
#    'but this one is wonderful',
#    "So close to my house which means it ' s so dangerous",
#    'Plenty of parking in the 5 points plaza',
#    'Make sure to get the pesto drizzle at the end',
#    ') - J'],
#   [array([0.075266  , 0.92421764, 0.03203384, 0.02165379, 0.03591212],
#          dtype=float32),
#    array([0.01497444, 0.5624735 , 0.26641345, 0.6700343 , 0.04696975],
#          dtype=float32),
#    array([0.97619665, 0.07969071, 0.06648381, 0.02510707, 0.18668824],
#          dtype=float32),
#    array([0.14015827, 0.9417835 , 0.04558684, 0.02210262, 0.00760586],
#          dtype=float32),
#    array([0.9534689 , 0.258731  , 0.05376922, 0.08440237, 0.17854945],
#          dtype=float32),
#    array([0.16670135, 0.86127126, 0.07403191, 0.01298356, 0.0359767 ],
#          dtype=float32),
#    array([0.00781556, 0.07425317, 0.69211614, 0.010555  , 0.30451804],
#          dtype=float32),
#    array([0.03351421, 0.8811329 , 0.07211346, 0.23530897, 0.00724863],
#          dtype=float32)]),
#  (['They get an instant review from me',
#    'This is a build your own pizza kind of place although they have some default menu',
#    'The service was quick and the staff was attentive',
#    'Easy 4 star',
#    'Keep it up'],
#   [array([0.01133174, 0.6802019 , 0.22137491, 0.07446928, 0.14839889],
#          dtype=float32),
#    array([0.58421016, 0.9071507 , 0.01962089, 0.00791278, 0.18084468],
#          dtype=float32),
#    array([0.04024203, 0.6161405 , 0.10103811, 0.8521324 , 0.01162247],
#          dtype=float32),
#    array([0.00641203, 0.86149853, 0.2344403 , 0.09899718, 0.01100336],
#          dtype=float32),
#    array([0.03189516, 0.08073784, 0.6219183 , 0.01377308, 0.08062648],
#          dtype=float32)]),
#  (['This is a great place to stop in and get a quick',
#    'hardy pizza and salad',
#    "There isn ' t anything else on the menu and the air conditioning is too cold for our liking",
#    'but they have really tasty pizza and salads served up quick',
#    'We are definitely returning here because they also have gluten - free pizza crust available and daiya cheese alternative for my lactose and gluten free children',
#    'We are happy'],
#   [array([0.07550678, 0.960914  , 0.07775559, 0.0211493 , 0.00867627],
#          dtype=float32),
#    array([0.8152086 , 0.04042469, 0.24962875, 0.01352559, 0.04680926],
#          dtype=float32),
#    array([0.75677365, 0.9338435 , 0.03305873, 0.04330003, 0.03149201],
#          dtype=float32),
#    array([0.1807825 , 0.96041596, 0.05092056, 0.01678398, 0.01223436],
#          dtype=float32),
#    array([0.845636  , 0.46469328, 0.08115722, 0.1911021 , 0.21021461],
#          dtype=float32),
#    array([0.07234712, 0.06169293, 0.66720366, 0.00753599, 0.03812182],
#          dtype=float32)]),
#  (['I called the State Street location at 6 : 40pm last night and placed my order for 1 pizza',
#    'I was told it would take 15 minutes and I could see the amount reflected as pending on my credit card',
#    'so the order definitely came through',
#    "I showed up 25 minutes later just after 7pm to be told by the worker at the register that he didn ' t know what I was talking about",
#    "He reluctantly asked the worker at the front of the line who writes the names on the papers and was told my pizza hadn ' t been made yet",
#    'They asked me to wait another 15 minutes and when I said that I was unhappy',
#    "the worker at the register shrugged his shoulders and said he didn ' t care",
#    'He said he was the manager',
#    'Needlessly to say I walked out',
#    'Seriously bad service'],
#   [array([0.985693  , 0.10987873, 0.0432567 , 0.01871531, 0.15412687],
#          dtype=float32),
#    array([0.75660956, 0.7543837 , 0.02388343, 0.54075164, 0.4219547 ],
#          dtype=float32),
#    array([0.9511045 , 0.04866391, 0.06904676, 0.02263061, 0.11400465],
#          dtype=float32),
#    array([0.9828644 , 0.11291991, 0.03828598, 0.02136279, 0.16372187],
#          dtype=float32),
#    array([0.937005  , 0.08980847, 0.04583418, 0.03191411, 0.6326572 ],
#          dtype=float32),
#    array([0.975404  , 0.33316255, 0.0440257 , 0.03879247, 0.09616902],
#          dtype=float32),
#    array([0.3994693 , 0.11083788, 0.05715555, 0.03312965, 0.93696165],
#          dtype=float32),
#    array([0.01711517, 0.03170397, 0.8519357 , 0.38138327, 0.00149469],
#          dtype=float32),
#    array([0.5314182 , 0.01900198, 0.38497987, 0.22846946, 0.07304517],
#          dtype=float32),
#    array([0.01562217, 0.03784215, 0.5132741 , 0.0114256 , 0.32071853],
#          dtype=float32)]),
#  (['This place is amazing',
#    'The pizza is delicious and inexpensive',
#    'Plus you can build your own pizza exactly the way you want it',
#    'The staff are all friendly',
#    'especially Tatiana',
#    'This is definitely my new go - to pizza spot'],
#   [array([0.08140424, 0.9166995 , 0.04978044, 0.01577747, 0.00593866],
#          dtype=float32),
#    array([0.01158924, 0.5066192 , 0.51926595, 0.01291432, 0.06573952],
#          dtype=float32),
#    array([0.33654732, 0.58505684, 0.0821824 , 0.01490276, 0.6604487 ],
#          dtype=float32),
#    array([0.02612644, 0.5152677 , 0.49106163, 0.01041078, 0.01082016],
#          dtype=float32),
#    array([0.03005607, 0.01066569, 0.89494795, 0.00509049, 0.02043006],
#          dtype=float32),
#    array([0.36387238, 0.8808251 , 0.09922015, 0.05193535, 0.00735835],
#          dtype=float32)]),
#  (['I have gotten pizza to go here several times',
#    'The service is very friendly and you get your pizza',
#    'made your way',
#    'pretty quickly',
#    'The pizza is alright',
#    'not great',
#    'but decent in a pinch and priced fairly for what you get',
#    'What separates this from really good pizza is the crust',
#    'it is like Wonder bread compared to artisan bakery bread',
#    'There is no complexity',
#    'structure',
#    'or chew to the crust',
#    'They have all the crusts already rolled out and ready to go throughout the day and night',
#    'The other issue is that they use the same couple of roller cutters to cut all the pizzas into slices so sometimes I have tasted BBQ sauce on my pizza because the pizza they cut prior to mine had BBQ sauce on it and it transfers to my pizza'],
#   [array([0.8422592 , 0.04714279, 0.1357486 , 0.00603768, 0.42773557],
#          dtype=float32),
#    array([0.06798003, 0.17071451, 0.4175434 , 0.01177353, 0.26290926],
#          dtype=float32),
#    array([0.04457802, 0.74042004, 0.15464114, 0.01120009, 0.05775637],
#          dtype=float32),
#    array([0.11221522, 0.0651782 , 0.64947426, 0.06917298, 0.01303104],
#          dtype=float32),
#    array([0.01735315, 0.28014448, 0.66614664, 0.00770464, 0.02450028],
#          dtype=float32),
#    array([0.085141  , 0.03737613, 0.8379369 , 0.01244316, 0.00235199],
#          dtype=float32),
#    array([0.02040244, 0.9687607 , 0.06976091, 0.01566255, 0.01879046],
#          dtype=float32),
#    array([0.07775568, 0.9410334 , 0.11234164, 0.03666735, 0.00487394],
#          dtype=float32),
#    array([0.01771137, 0.09112435, 0.9091745 , 0.00529642, 0.00725755],
#          dtype=float32),
#    array([0.33022842, 0.7979245 , 0.04077502, 0.06148179, 0.00765716],
#          dtype=float32),
#    array([0.07704458, 0.44677126, 0.37921175, 0.03703071, 0.00784838],
#          dtype=float32),
#    array([0.0113655 , 0.7635778 , 0.36104542, 0.12306345, 0.00727166],
#          dtype=float32),
#    array([0.79609704, 0.10779075, 0.18383989, 0.02814468, 0.20489193],
#          dtype=float32),
#    array([0.980362  , 0.16610654, 0.03824385, 0.02574015, 0.09877528],
#          dtype=float32)]),
#  (["I ' ve been to many Blaze locations and when the state street location first opened",
#    'we were so excited',
#    'We were loyal customers for a while',
#    "as the service was always fast and friendly but lately we ' ve noticed a disappointing decline in the customer service",
#    "The past two times we ' ve been ( including tonight ) the service was painfully slow",
#    "and the employees looked miserable and didn ' t even acknowledge us",
#    'Upon arriving',
#    'I said " hello " and barely got a " hi " back',
#    'And when I left',
#    "I thanked the girl boxing up my pizza and she didn ' t even respond or even look in my direction",
#    'The pizza is always great but it just seems as the employees need a morale boost',
#    "Probably won ' t be coming back for some time",
#    'unfortunately'],
#   [array([0.64982134, 0.03250905, 0.02889928, 0.01780069, 0.9201635 ],
#          dtype=float32),
#    array([0.61836016, 0.6725483 , 0.05054881, 0.0176767 , 0.02315489],
#          dtype=float32),
#    array([0.23386328, 0.02212101, 0.28134707, 0.00560388, 0.55180657],
#          dtype=float32),
#    array([0.21523188, 0.81354433, 0.10245086, 0.04549364, 0.6187326 ],
#          dtype=float32),
#    array([0.22136848, 0.595136  , 0.03737739, 0.15357542, 0.5754152 ],
#          dtype=float32),
#    array([0.11533712, 0.949764  , 0.18715374, 0.01723685, 0.01888364],
#          dtype=float32),
#    array([0.03833248, 0.01384882, 0.91847706, 0.01783374, 0.00603323],
#          dtype=float32),
#    array([0.94446445, 0.65267265, 0.01971754, 0.04337502, 0.05839936],
#          dtype=float32),
#    array([0.7829261 , 0.40836722, 0.11323432, 0.02694238, 0.01523029],
#          dtype=float32),
#    array([0.9381603 , 0.7617337 , 0.01965236, 0.02245419, 0.06569993],
#          dtype=float32),
#    array([0.21105358, 0.10670312, 0.23345846, 0.0048709 , 0.739596  ],
#          dtype=float32),
#    array([0.03325326, 0.7127749 , 0.4331049 , 0.08526376, 0.00396253],
#          dtype=float32),
#    array([0.04764405, 0.02409811, 0.8787081 , 0.04628081, 0.00583725],
#          dtype=float32)]),
#  (['Best pizza we have EVER had',
#    'The staff needs to pick it up a little',
#    'Waited 15 min to order',
#    'they all moved like they had been smoking Definitely will come back'],
#   [array([0.03841156, 0.00645063, 0.90570456, 0.00214444, 0.0115887 ],
#          dtype=float32),
#    array([0.08334408, 0.20808622, 0.63289475, 0.04093682, 0.02357637],
#          dtype=float32),
#    array([0.56063664, 0.00720616, 0.46459782, 0.0166572 , 0.04088549],
#          dtype=float32),
#    array([0.2682134 , 0.5324196 , 0.09264343, 0.4017373 , 0.42582136],
#          dtype=float32)]),
#  (['Great pizza full customizable and awesome quality for not only the meat eater but a vegan delight also',
#    'the staff was awesome they made you feel welcome ps try the brownies'],
#   [array([0.46382508, 0.9262212 , 0.02590695, 0.00572317, 0.20405363],
#          dtype=float32),
#    array([0.05018128, 0.9539214 , 0.05309207, 0.03955523, 0.00480943],
#          dtype=float32)]),
#  (['When you order take - out',
#    'they put the pizza in the box',
#    'directly on top of a receipt printed on thermal paper',
#    "I really wish they didn ' t do this because thermal paper could contain BPA or other harmful chemicals",
#    'which are not healthy to ingest',
#    "We ' ve ordered take - out one time and have been hesitant to do so again because of this",
#    'To see what I mean',
#    'look at the picture uploaded by Cheng L',
#    'on 9 / 12 / 17',
#    "My question is : Why can ' t they just put the receipt on the outside of the box instead of underneath the pizza"],
#   [array([0.24908412, 0.5631265 , 0.08073865, 0.07994776, 0.07007688],
#          dtype=float32),
#    array([0.01526875, 0.4882748 , 0.46222958, 0.01662748, 0.08120133],
#          dtype=float32),
#    array([0.14815076, 0.91325235, 0.09611646, 0.06312507, 0.24850255],
#          dtype=float32),
#    array([0.9665784 , 0.772812  , 0.02057101, 0.05527024, 0.06348209],
#          dtype=float32),
#    array([0.05052291, 0.8790445 , 0.07711142, 0.06621566, 0.01048082],
#          dtype=float32),
#    array([0.8581718 , 0.88993704, 0.02392832, 0.03182042, 0.02335843],
#          dtype=float32),
#    array([0.709598  , 0.07683509, 0.32374102, 0.05850495, 0.01946388],
#          dtype=float32),
#    array([0.06283688, 0.03658481, 0.05908265, 0.00753927, 0.94913286],
#          dtype=float32),
#    array([0.03967605, 0.9362726 , 0.07965764, 0.16232091, 0.00297292],
#          dtype=float32),
#    array([0.05006585, 0.43740976, 0.1307963 , 0.00217317, 0.5744883 ],
#          dtype=float32)]),
#  (['Had the " thick " crust Build Your Own last night n again for lunch today',
#    "I ' m a Deep Dish Chicago Style pizza lover n they did a good job"],
#   [array([0.60598946, 0.9176292 , 0.05339935, 0.14445859, 0.03657316],
#          dtype=float32),
#    array([0.96191406, 0.05877297, 0.07543472, 0.02347025, 0.19859582],
#          dtype=float32)]),
#  (['Love this place',
#    'Their pizza is FANTASTIC',
#    'and their salad is pretty good too',
#    "It ' s line style so you can see all the different ingredients available to you so that you know exactly what you ' re getting",
#    'In my opinion',
#    'everything not only looks',
#    'but tastes of high quality',
#    'I especially love their selection of drinks',
#    'The root beer is to DIE FOR',
#    "Sure they don ' t have the usual classics that most people have ( i",
#    'e',
#    'Coca - Cola',
#    'sprite',
#    'etc',
#    ') but I personally feel that what they do have ( a few kinds of soda and different flavors of very nice Aqua Fresca ) goes along PERFECTLY with their style - both taste and atmosphere',
#    "If you haven ' t tried this place yet",
#    'I encourage you to go as soon as you get a chance',
#    "I promise you ' ll love it : )"],
#   [array([0.76063436, 0.46167457, 0.05990105, 0.00977218, 0.02673684],
#          dtype=float32),
#    array([0.10580115, 0.14592984, 0.63420105, 0.03086051, 0.00443836],
#          dtype=float32),
#    array([0.02069037, 0.06982793, 0.8684111 , 0.02373606, 0.02846842],
#          dtype=float32),
#    array([0.5370904 , 0.04234395, 0.08367522, 0.02208552, 0.8696099 ],
#          dtype=float32),
#    array([0.02936566, 0.91972744, 0.10221238, 0.02181777, 0.01459697],
#          dtype=float32),
#    array([0.0167479 , 0.05717265, 0.93207   , 0.01193059, 0.00156343],
#          dtype=float32),
#    array([0.01608403, 0.9273283 , 0.09981814, 0.03324322, 0.04629035],
#          dtype=float32),
#    array([0.934477  , 0.0256718 , 0.17249885, 0.00869897, 0.0354165 ],
#          dtype=float32),
#    array([0.0145813 , 0.20679834, 0.7052121 , 0.02262061, 0.02148759],
#          dtype=float32),
#    array([0.6717957 , 0.85841453, 0.06935166, 0.00854927, 0.04853272],
#          dtype=float32),
#    array([0.02751505, 0.02364588, 0.8972032 , 0.03018422, 0.00614845],
#          dtype=float32),
#    array([0.00807434, 0.19891374, 0.8281471 , 0.01742173, 0.00151658],
#          dtype=float32),
#    array([0.04179707, 0.02151909, 0.9053325 , 0.01121401, 0.00666776],
#          dtype=float32),
#    array([0.16484913, 0.03111668, 0.7505402 , 0.02492552, 0.00540883],
#          dtype=float32),
#    array([0.9470185 , 0.80396473, 0.01093461, 0.02716995, 0.05102021],
#          dtype=float32),
#    array([0.9616847 , 0.16668978, 0.05869901, 0.01362479, 0.04849285],
#          dtype=float32),
#    array([0.42186257, 0.10359593, 0.05013038, 0.01806998, 0.92750716],
#          dtype=float32),
#    array([0.95505303, 0.30418894, 0.03476011, 0.02453412, 0.07088733],
#          dtype=float32)]),
#  (['Today',
#    'Tuesday',
#    'may 22nd',
#    'I decided to go to blaze pizza for my lunch around 12ish pm with my co - worker',
#    'And was immediately greeted by two super nice ladies',
#    'Instantly felt a nice vibe',
#    "Made sure to ask me questions regarding how I ' d like my pizza made",
#    "Then the Blazer who was actually blazing my pie was also asking me how I ' d like my pizza cooked",
#    "Which surprised me because usually wood fired pizza places don ' t ask me how I ' d like my pizza cooked",
#    'Also in the middle of me eating pizza the two super nice ladies came back to see if me and my co - worker was doing alright',
#    'They were super nice about it',
#    'As I left they aslo said good bye and to have a nice day which is always nice to hear',
#    'Overall I think the staff went out of their way to make sure I had a satisfactory experience',
#    "They ' re super nice and deliver exceptional customer service"],
#   [array([0.02666862, 0.00766718, 0.9136149 , 0.00903144, 0.0193486 ],
#          dtype=float32),
#    array([0.11206944, 0.03881662, 0.762169  , 0.02375485, 0.00885533],
#          dtype=float32),
#    array([0.00582729, 0.00811333, 0.9206093 , 0.00952755, 0.05424465],
#          dtype=float32),
#    array([0.7903011 , 0.08498708, 0.0729965 , 0.02430154, 0.5541905 ],
#          dtype=float32),
#    array([0.03030404, 0.03676762, 0.4537132 , 0.24284941, 0.6214652 ],
#          dtype=float32),
#    array([0.01029965, 0.76973796, 0.11861274, 0.18007235, 0.03169376],
#          dtype=float32),
#    array([0.9490215 , 0.71944475, 0.02538026, 0.03185082, 0.05010638],
#          dtype=float32),
#    array([0.23787785, 0.8840831 , 0.0756082 , 0.06254224, 0.60481954],
#          dtype=float32),
#    array([0.47482696, 0.80462456, 0.14426401, 0.00296627, 0.0125862 ],
#          dtype=float32),
#    array([0.08341917, 0.54496783, 0.08601253, 0.06359164, 0.81421363],
#          dtype=float32),
#    array([0.04493211, 0.17241387, 0.38677618, 0.38727927, 0.09590105],
#          dtype=float32),
#    array([0.933727  , 0.44589496, 0.0398623 , 0.0778608 , 0.2913053 ],
#          dtype=float32),
#    array([0.9690612 , 0.3379414 , 0.03743764, 0.01924308, 0.10438319],
#          dtype=float32),
#    array([0.63901365, 0.18308365, 0.24901138, 0.08143319, 0.10696055],
#          dtype=float32)]),
#  (['My new pizza spot',
#    'Love creating my own w / unlimited toppings for one low price',
#    'Friendly staff',
#    'Love the app'],
#   [array([0.10075955, 0.15027432, 0.6655792 , 0.0257028 , 0.00736201],
#          dtype=float32),
#    array([0.9485823 , 0.68143785, 0.02452787, 0.03481209, 0.04654364],
#          dtype=float32),
#    array([0.02495618, 0.8187672 , 0.19269833, 0.03673361, 0.0067249 ],
#          dtype=float32),
#    array([0.5515528 , 0.04083117, 0.34557414, 0.00549973, 0.07023167],
#          dtype=float32)]),
#  (['Thank you for the delicious food',
#    'Have so many options and did I mention that they even have VEGAN options',
#    ': ) )'],
#   [array([0.01420387, 0.03039741, 0.8198884 , 0.01501971, 0.05070326],
#          dtype=float32),
#    array([0.9568125 , 0.0542665 , 0.09798719, 0.0256871 , 0.18671013],
#          dtype=float32),
#    array([0.03061874, 0.9509844 , 0.04965124, 0.03550385, 0.006537  ],
#          dtype=float32)]),
#  (["I ' ve been going to Blaze in Sacramento for years and am so glad to now have one local",
#    'The pizza is amazing',
#    'prices are great',
#    'the staff is friendly and efficient',
#    'the blood orange lemonade is soooo good and they have yummy smores',
#    'I definitely recommend Blaze Pizza'],
#   [array([0.96668226, 0.0611783 , 0.08572777, 0.01708497, 0.12906119],
#          dtype=float32),
#    array([0.04183311, 0.7928991 , 0.18027787, 0.01660478, 0.00760864],
#          dtype=float32),
#    array([0.32341263, 0.01501258, 0.6824498 , 0.00243572, 0.01729021],
#          dtype=float32),
#    array([0.01341419, 0.80330455, 0.2628206 , 0.01735523, 0.01713442],
#          dtype=float32),
#    array([0.04645856, 0.4794713 , 0.5861632 , 0.00706349, 0.02862125],
#          dtype=float32),
#    array([0.81982315, 0.00844421, 0.24531564, 0.03161336, 0.05593101],
#          dtype=float32)]),
#  (['As much as I love Blaze pizza',
#    'this location has gone downhill fast since opening',
#    'Last night I went to order a pizza after work around 8 : 30',
#    'I have visited this specific location many times and have had good service and bad service',
#    'it depends on the staff',
#    "Last night was the worst service I ' ve ever had",
#    'When I first walked up to the building there were a group of kids smoking a joint right outside the door',
#    'not terrible',
#    'but you could smell it inside',
#    'As I walked in',
#    'all the staff behind the counter were laughing a playing',
#    'also not terrible',
#    'but there was a line of 5 people and no one in the lineup making the pizzas',
#    'only one girls who was both taking the order and starting the pizzas',
#    'Finally one girl came from the back and started on the pizzas',
#    'These two girls were great and helpful',
#    'I ordered and my pizza was made',
#    'about to go to the oven',
#    'There was a shorter guy putting the pizzas in the oven',
#    'and then in walks one of this kids smoking the joint outside',
#    'She get behind the counter and starts play hitting the guy putting the pizzas in the oven',
#    'She was obviously very high',
#    "She could figure out how to use the cash resister and couldn ' t read my order",
#    "She ended up giving me my salad for free because she couldn ' t find where to input the salad",
#    'Then',
#    'after the pizza was fired and brought out',
#    'all of the pizzas made at the same time had the wrong ticket attached and we all had our orders mixed up',
#    "I left with my pizza after they finally figured out who ' s belonged to whom",
#    'While I was eating my pizza',
#    'I found 5 long black hairs in almost each slice',
#    'so I threw it away and walked out',
#    "I ' ve been to this location many times since it ' s opened",
#    'and like I mentioned',
#    'there are good visits and bad visits',
#    'But this was the worst',
#    'And it all comes down to the staff',
#    'I understand having fun at work',
#    'but hitting each other with the pizza trays',
#    'being too high to work and being dirty is just not something you want when it comes to food',
#    'Sorry Blaze',
#    'you had a good thing going',
#    'but you hired the wrong people'],
#   [array([0.5539019 , 0.0216107 , 0.03445994, 0.02129506, 0.91483366],
#          dtype=float32),
#    array([0.01602284, 0.9151902 , 0.07062846, 0.2585743 , 0.06451148],
#          dtype=float32),
#    array([0.9663397 , 0.08667311, 0.04348246, 0.02474589, 0.37286898],
#          dtype=float32),
#    array([0.85564816, 0.6077785 , 0.03621993, 0.01819711, 0.32460472],
#          dtype=float32),
#    array([0.01252956, 0.82901454, 0.30105507, 0.03927417, 0.00650207],
#          dtype=float32),
#    array([0.9300201 , 0.0269889 , 0.10981949, 0.03771019, 0.19281845],
#          dtype=float32),
#    array([0.9492752 , 0.06656304, 0.06449473, 0.05143577, 0.39385608],
#          dtype=float32),
#    array([0.02736724, 0.00853321, 0.8841922 , 0.01234386, 0.01783002],
#          dtype=float32),
#    array([0.01290532, 0.00685906, 0.8183161 , 0.03347083, 0.08730795],
#          dtype=float32),
#    array([0.5694146 , 0.1820327 , 0.07686836, 0.00618668, 0.34889144],
#          dtype=float32),
#    array([0.00737822, 0.5986532 , 0.371406  , 0.11680097, 0.2676848 ],
#          dtype=float32),
#    array([0.02933812, 0.00943089, 0.71587396, 0.01260563, 0.24102204],
#          dtype=float32),
#    array([0.07413012, 0.9688495 , 0.07077482, 0.01843749, 0.219954  ],
#          dtype=float32),
#    array([0.05896196, 0.05144344, 0.04738611, 0.05665466, 0.980667  ],
#          dtype=float32),
#    array([0.02349845, 0.9550824 , 0.12681085, 0.02830487, 0.01165018],
#          dtype=float32),
#    array([0.11130895, 0.91432536, 0.11904967, 0.03891148, 0.02188485],
#          dtype=float32),
#    array([0.9441757 , 0.14196199, 0.07668759, 0.06947645, 0.08589278],
#          dtype=float32),
#    array([0.00356425, 0.00482729, 0.9697449 , 0.00479153, 0.02386494],
#          dtype=float32),
#    array([0.0122146 , 0.8260445 , 0.20856084, 0.65799636, 0.05813745],
#          dtype=float32),
#    array([0.1305749 , 0.95023584, 0.08473658, 0.10372604, 0.00782933],
#          dtype=float32),
#    array([0.05588317, 0.9336579 , 0.19411671, 0.01891666, 0.08866008],
#          dtype=float32),
#    array([0.04020749, 0.7401915 , 0.08347324, 0.7367408 , 0.00620865],
#          dtype=float32),
#    array([0.17093936, 0.0362209 , 0.53470445, 0.00213903, 0.25038213],
#          dtype=float32),
#    array([0.41858247, 0.8612451 , 0.15275161, 0.01282493, 0.01380649],
#          dtype=float32),
#    array([0.04453878, 0.03329619, 0.84825945, 0.0206368 , 0.00513266],
#          dtype=float32),
#    array([0.07416324, 0.45334688, 0.35950905, 0.41648182, 0.0155149 ],
#          dtype=float32),
#    array([0.6253277, 0.2068575, 0.0585029, 0.0694317, 0.7999326],
#          dtype=float32),
#    array([0.9453665 , 0.19092081, 0.09489182, 0.07886539, 0.13777547],
#          dtype=float32),
#    array([0.8726884 , 0.12580544, 0.14536428, 0.17527561, 0.04235948],
#          dtype=float32),
#    array([0.38854867, 0.88368726, 0.02060157, 0.12620729, 0.5854291 ],
#          dtype=float32),
#    array([0.9740146 , 0.06496945, 0.07637995, 0.01015   , 0.05809744],
#          dtype=float32),
#    array([0.47888446, 0.09615751, 0.01938789, 0.03860521, 0.96399766],
#          dtype=float32),
#    array([0.9251367 , 0.10471898, 0.12666456, 0.01756154, 0.03029636],
#          dtype=float32),
#    array([0.78590506, 0.10949051, 0.22774193, 0.01120016, 0.07459657],
#          dtype=float32),
#    array([0.03255824, 0.74355173, 0.12328556, 0.5847266 , 0.01061442],
#          dtype=float32),
#    array([0.00850387, 0.3546941 , 0.7129322 , 0.02108514, 0.04309653],
#          dtype=float32),
#    array([0.9735575 , 0.09429055, 0.05557149, 0.00840311, 0.13578503],
#          dtype=float32),
#    array([0.06223422, 0.20463164, 0.593645  , 0.09340599, 0.03173807],
#          dtype=float32),
#    array([0.77970266, 0.34807387, 0.17655212, 0.01616018, 0.01910078],
#          dtype=float32),
#    array([0.01913563, 0.00757694, 0.8716308 , 0.00479791, 0.06835036],
#          dtype=float32),
#    array([0.05100976, 0.35703057, 0.23905186, 0.04827959, 0.1921227 ],
#          dtype=float32),
#    array([0.02985743, 0.7812314 , 0.16031098, 0.00925552, 0.02322159],
#          dtype=float32)]),
#  (['Not only does Blaze have delicious food',
#    'but also amazing customer service',
#    'If you \' re trying to choose a " build your own " pizza place ( Persona',
#    'Pizza Rev',
#    'Pieology',
#    'Pizza Guru',
#    'and Blaze ) hands down Blaze takes the cake ( or pie )'],
#   [array([0.00642568, 0.01446508, 0.97280216, 0.00434525, 0.00395949],
#          dtype=float32),
#    array([0.0590626 , 0.90391743, 0.07420819, 0.01525893, 0.01217758],
#          dtype=float32),
#    array([0.83960736, 0.47428977, 0.02867282, 0.03252185, 0.35793215],
#          dtype=float32),
#    array([0.038076  , 0.01223991, 0.8770293 , 0.01102075, 0.01819821],
#          dtype=float32),
#    array([0.10149764, 0.08633558, 0.5535173 , 0.31874374, 0.00560976],
#          dtype=float32),
#    array([0.08276384, 0.0264034 , 0.72062755, 0.0347272 , 0.03045053],
#          dtype=float32),
#    array([0.03195276, 0.96879834, 0.03886198, 0.01100139, 0.01466807],
#          dtype=float32)]),
#  (["I ' m in LOVE",
#    'Under $ 10 for a 6 slice pizza with all / any of the toppings you want ( including Daiya cheese',
#    ')',
#    'The crust in thin and perfect',
#    'Cooks in something like 3 min - so so tasty',
#    "And they ' re open til 10 - One of my new favorite go to spots"],
#   [array([0.97518224, 0.11490156, 0.0541702 , 0.01115898, 0.08857532],
#          dtype=float32),
#    array([0.07470922, 0.2789162 , 0.36297953, 0.01372939, 0.20270844],
#          dtype=float32),
#    array([0.03551665, 0.89341974, 0.08856834, 0.05746823, 0.00886315],
#          dtype=float32),
#    array([0.01495941, 0.9009562 , 0.16780688, 0.10713477, 0.00508157],
#          dtype=float32),
#    array([0.8765982 , 0.5979781 , 0.06334624, 0.00500823, 0.04046559],
#          dtype=float32),
#    array([0.09428115, 0.19161916, 0.7692426 , 0.00481441, 0.03267187],
#          dtype=float32)]),
#  (['So bummed',
#    'Was craving Blaze tonight',
#    'My 18 year old son went in and ordered two bbq chicken pizzas one with no banana peppers',
#    'one plain peoperoni',
#    'and one art lovers',
#    'Came home with two bbq chickens with added blue cheese which we hate',
#    'both of which had banana peppers',
#    'one sort of artlover but did not have dollops of red sauce',
#    'the entire thing was covered and there was no mozzerella',
#    'and one with onion',
#    'turkey meatballs',
#    'mozzerella and marinara',
#    'I tried to call when we looked at the order and it just goes to voicemail',
#    'I have sent people over but this was horrible',
#    'Really disappointed that I couldnt call in'],
#   [array([0.8226267 , 0.05740388, 0.24113415, 0.0183165 , 0.0266466 ],
#          dtype=float32),
#    array([0.00472841, 0.04075305, 0.7012736 , 0.2834666 , 0.09329135],
#          dtype=float32),
#    array([0.1521003 , 0.51961124, 0.3053325 , 0.00433323, 0.05706389],
#          dtype=float32),
#    array([0.1149089 , 0.9252047 , 0.05227208, 0.01744409, 0.00721433],
#          dtype=float32),
#    array([0.26530674, 0.2881272 , 0.47715983, 0.03622992, 0.00994463],
#          dtype=float32),
#    array([0.02371047, 0.18896489, 0.7673173 , 0.03252573, 0.03242099],
#          dtype=float32),
#    array([0.0669    , 0.69014174, 0.13507953, 0.2519726 , 0.01057912],
#          dtype=float32),
#    array([0.47340718, 0.38674387, 0.31058696, 0.006828  , 0.01013985],
#          dtype=float32),
#    array([0.03675944, 0.18455066, 0.23389737, 0.95495385, 0.11831231],
#          dtype=float32),
#    array([0.253602  , 0.03416895, 0.5825006 , 0.01427028, 0.09874759],
#          dtype=float32),
#    array([0.02349998, 0.52542555, 0.4359646 , 0.10141777, 0.00340847],
#          dtype=float32),
#    array([0.13598344, 0.02390353, 0.7384774 , 0.01493169, 0.01780049],
#          dtype=float32),
#    array([0.9332245 , 0.02605024, 0.12579875, 0.0233263 , 0.10798814],
#          dtype=float32),
#    array([0.90792066, 0.3959838 , 0.03152014, 0.07270113, 0.3077941 ],
#          dtype=float32),
#    array([0.9567473 , 0.7100668 , 0.02363737, 0.04950482, 0.05975934],
#          dtype=float32)]),
#  (["It ' s our first time in blaze in Santa Barbara in this location all the employees are super nice the lady who helped us for name is Haley very nice lady very helpful and the manager Bobby he was nice guy also we really high recommended this place pizza location very nice and the pizza is excellent like always"],
#   [array([0.9504358 , 0.80024844, 0.00884185, 0.03277951, 0.04989126],
#          dtype=float32)]),
#  (['Awful',
#    'Greasy pizza with way too much salt and garlic ( the green stripe ) and The Caesar salad had no flavor with soggy stale textured croutons Second try and both times very disappointed',
#    'Horrible after taste',
#    'Never again'],
#   [array([0.0409418 , 0.02308096, 0.88475305, 0.01616242, 0.00588576],
#          dtype=float32),
#    array([0.8971101 , 0.9024058 , 0.02453308, 0.07423533, 0.02779423],
#          dtype=float32),
#    array([0.00230573, 0.01159917, 0.9491595 , 0.00877311, 0.03851381],
#          dtype=float32),
#    array([0.04960482, 0.67145324, 0.22269392, 0.10323661, 0.00380626],
#          dtype=float32)]),
#  (['Blaze pizza aka Blasé pizza',
#    "It ' s another run of the mill pizza joint",
#    'Cheese must have been in short supply because my pizzas where woefully lacking any'],
#   [array([0.0164967 , 0.0163327 , 0.8801193 , 0.01229626, 0.03653109],
#          dtype=float32),
#    array([0.44446817, 0.01012659, 0.6431277 , 0.01085503, 0.04853242],
#          dtype=float32),
#    array([0.01384362, 0.4190171 , 0.24622138, 0.09102523, 0.47038725],
#          dtype=float32)]),
#  (["HAIR IN THE FOOD - Each of the 2 times I ' ve been there",
#    'I found hair in our food',
#    'This past Sunday',
#    'there was hair in 3 of the 4 pizzas',
#    "I can ' t go back there"],
#   [array([0.43593374, 0.13428234, 0.23249088, 0.00500292, 0.55812776],
#          dtype=float32),
#    array([0.6949635 , 0.73631656, 0.04216868, 0.07506834, 0.0143027 ],
#          dtype=float32),
#    array([0.46857822, 0.46408167, 0.11624733, 0.02319417, 0.01504855],
#          dtype=float32),
#    array([0.00617844, 0.6811614 , 0.1291282 , 0.8304363 , 0.05660819],
#          dtype=float32),
#    array([0.9605608 , 0.36703926, 0.05084629, 0.012076  , 0.06699793],
#          dtype=float32)]),
#  (['The best',
#    'They have a huge variety of veggies And they have vegan cheese and " chicken " love it'],
#   [array([0.01770978, 0.00860697, 0.9515967 , 0.00481922, 0.01180765],
#          dtype=float32),
#    array([0.7736715 , 0.28110036, 0.1898989 , 0.0766094 , 0.09795403],
#          dtype=float32)]),
#  (['Man this place is bad',
#    "The pizza wasn ' t cooked",
#    'dough was leaden and all the toppings tasted canned',
#    "Cheese seemed powdery - like pre - grated cheese from a bag ( not something I ' d usually eat )",
#    'Seriously',
#    'you are better off getting a frozen pizza',
#    "It will taste better and you won ' t have to deal with teenagers"],
#   [array([0.03297554, 0.83325493, 0.1912994 , 0.01988677, 0.00911841],
#          dtype=float32),
#    array([0.06360407, 0.21872367, 0.7505971 , 0.00520151, 0.01056416],
#          dtype=float32),
#    array([0.49104717, 0.6825226 , 0.07212923, 0.6253805 , 0.1333809 ],
#          dtype=float32),
#    array([0.37116697, 0.9566968 , 0.05453191, 0.01246353, 0.01839682],
#          dtype=float32),
#    array([0.01812475, 0.04558408, 0.864961  , 0.01608955, 0.00533281],
#          dtype=float32),
#    array([0.02893554, 0.01391437, 0.48628387, 0.00430571, 0.57144463],
#          dtype=float32),
#    array([0.0101085 , 0.048134  , 0.8605232 , 0.01983155, 0.09602433],
#          dtype=float32)]),
#  (['I enjoyed being able to build my own pizza and the toppings they had',
#    'I also liked the selection of drinks they had and salad options',
#    'The pizza dough tasted delicious',
#    'However',
#    'I feel like Pizza Rev has more topping choices',
#    'I also found it interesting that the meat lovers pizza on the menu only had two meats on it',
#    'And no bacon options',
#    "The tables are family style and there isn ' t much space but it ' s cozy",
#    'But despite that',
#    'it was a pretty decent pizza place'],
#   [array([0.97591525, 0.07230234, 0.06146536, 0.01255914, 0.08598779],
#          dtype=float32),
#    array([0.88822377, 0.02085678, 0.22662976, 0.01238022, 0.04770019],
#          dtype=float32),
#    array([0.05050129, 0.58902603, 0.27238843, 0.01016565, 0.05304628],
#          dtype=float32),
#    array([0.01397646, 0.01880283, 0.91182816, 0.01159949, 0.01235548],
#          dtype=float32),
#    array([0.9443224 , 0.3046563 , 0.08011798, 0.02396085, 0.03137146],
#          dtype=float32),
#    array([0.96573395, 0.25918484, 0.05692061, 0.0441733 , 0.06230886],
#          dtype=float32),
#    array([0.09703792, 0.7741244 , 0.1485881 , 0.06705236, 0.00632138],
#          dtype=float32),
#    array([0.8796716 , 0.18134709, 0.03955802, 0.08485781, 0.6642682 ],
#          dtype=float32),
#    array([0.01996405, 0.35442242, 0.40392214, 0.09635221, 0.01599465],
#          dtype=float32),
#    array([0.01884311, 0.15000516, 0.41299906, 0.7860623 , 0.07627928],
#          dtype=float32)]),
#  (['I have been very disappointed with this location recently',
#    "I don ' t like writing reviews but today just did it for me",
#    'There was one girl working the line who was great and very helpful to the first timers behind us',
#    'When it was my turn to pay The register girl Jay was very rude',
#    'She starts to put my order in and walks away',
#    'Im standing there for 5 minutes while she cuts the pizza and walks in the back',
#    'When she finally comes to finish my transaction she is very short',
#    'When she calls my order to be picked up I say thank you and she just looks at me and cuts the next pizza which was my sisters',
#    'She had asked for ranch and glaze on the side and she puts it on the pizza',
#    'She looks like she hates her job',
#    'looks annoyed when customers ask for something',
#    'Every once else was great and loved coming to this location but today I was very disappointed'],
#   [array([0.9728486 , 0.08276203, 0.04255013, 0.02301924, 0.24095744],
#          dtype=float32),
#    array([0.9137389 , 0.06549549, 0.17566459, 0.0093029 , 0.02038379],
#          dtype=float32),
#    array([0.32686597, 0.93034834, 0.05959253, 0.3429574 , 0.01008322],
#          dtype=float32),
#    array([0.0138683 , 0.51256895, 0.25582653, 0.85241604, 0.08271319],
#          dtype=float32),
#    array([0.07419809, 0.8934814 , 0.16527481, 0.02628737, 0.00862403],
#          dtype=float32),
#    array([0.39688516, 0.5253582 , 0.04739021, 0.07962265, 0.7866897 ],
#          dtype=float32),
#    array([0.06203092, 0.8973218 , 0.21793957, 0.07698518, 0.00256619],
#          dtype=float32),
#    array([0.94026405, 0.6734213 , 0.01434173, 0.04553606, 0.04558125],
#          dtype=float32),
#    array([0.5062293 , 0.90904194, 0.081249  , 0.1251435 , 0.01467812],
#          dtype=float32),
#    array([0.11564641, 0.83702856, 0.08542527, 0.8035845 , 0.00679483],
#          dtype=float32),
#    array([0.06418645, 0.24832939, 0.690389  , 0.01337448, 0.01083366],
#          dtype=float32),
#    array([0.7581341 , 0.71322656, 0.03195223, 0.69094455, 0.29601365],
#          dtype=float32)]),
#  (["This restaurant is much better than the previous establishment and I ' m glad they are here",
#    "I ' m not a fan of fast food in general",
#    'but they put out a decent and fresh product',
#    'The " assembly line " style of fast food is taking over and pizza seems to be one of the more popular options',
#    'Blaze is good',
#    "the food seems to be good quality and isn ' t expensive for what you get",
#    'I believe the build your own option is less than $ 10',
#    'If you really add up the toppings it can really be a decent pizza and most people would end up saving a bit to take home',
#    'The few times I have visit',
#    "I didn ' t wait long for my pizza to get done",
#    'If we have to have fast food in existence',
#    "this isn ' t a bad option"],
#   [array([0.97137004, 0.36680016, 0.05232604, 0.03091818, 0.04805721],
#          dtype=float32),
#    array([0.9630568 , 0.21920328, 0.04603023, 0.01180323, 0.08148023],
#          dtype=float32),
#    array([0.09532536, 0.861212  , 0.09468812, 0.11406566, 0.30359244],
#          dtype=float32),
#    array([0.8926203 , 0.2657873 , 0.15168607, 0.04813771, 0.1033097 ],
#          dtype=float32),
#    array([0.04606964, 0.10582207, 0.7874812 , 0.00666345, 0.00575273],
#          dtype=float32),
#    array([0.25249043, 0.01808708, 0.26878977, 0.00756939, 0.6553936 ],
#          dtype=float32),
#    array([0.74292576, 0.12348229, 0.10254491, 0.00713644, 0.66477084],
#          dtype=float32),
#    array([0.9604617 , 0.08635585, 0.06147863, 0.02779188, 0.372843  ],
#          dtype=float32),
#    array([0.93008995, 0.0315792 , 0.19230932, 0.0088846 , 0.0465067 ],
#          dtype=float32),
#    array([0.82915646, 0.25330654, 0.21648993, 0.0430503 , 0.00988402],
#          dtype=float32),
#    array([0.55297816, 0.2659335 , 0.1868177 , 0.09402948, 0.01988382],
#          dtype=float32),
#    array([0.03560882, 0.91663355, 0.09232074, 0.02335763, 0.0647049 ],
#          dtype=float32)]),
#  (['Solid 3 stars',
#    'Pretty decent pizza',
#    'Service is friendly',
#    'enthusiastic and swift',
#    'They really do keep the line moving along in a timely manner',
#    'When ordering',
#    'you have a choice between one of their custom made pies or " build your own "',
#    'I opted for the latter with just pepperoni and mushroom',
#    'The toppings were a little sparse for my liking',
#    'I think if you want yours loaded',
#    'you should order a lot of different acoutrements',
#    'From the time I placed my order to the time out the door was about 15 minutes',
#    'and this was on their second day of operation',
#    'Not bad',
#    'considering',
#    "As far as the pizza goes it ' s pretty good",
#    'although my box felt pretty light when I received it and I almost had to make sure that it was in there',
#    'It is a pretty tasty pie',
#    'and as I mentioned earlier',
#    'not loaded with very many toppings',
#    'My only other minor gripe is I wish that the crust was just a little more well done',
#    'It was kinda soft and a little chewy',
#    'Again',
#    'no biggie',
#    'Overall',
#    'pretty good pizza and great service',
#    'Would I return',
#    'Definitely'],
#   [array([0.00938671, 0.01868141, 0.9333622 , 0.03107367, 0.00587962],
#          dtype=float32),
#    array([0.03831574, 0.06556138, 0.42296603, 0.05833651, 0.25162342],
#          dtype=float32),
#    array([0.02613443, 0.5445707 , 0.33668515, 0.03486923, 0.00952864],
#          dtype=float32),
#    array([0.02260191, 0.43582332, 0.29520327, 0.03845454, 0.0476578 ],
#          dtype=float32),
#    array([0.06402189, 0.929619  , 0.1478223 , 0.03802737, 0.17673302],
#          dtype=float32),
#    array([0.01644379, 0.19459401, 0.5216702 , 0.01336067, 0.10485292],
#          dtype=float32),
#    array([0.81916124, 0.42727026, 0.0321837 , 0.05790377, 0.47058553],
#          dtype=float32),
#    array([0.9519287 , 0.19136448, 0.05215908, 0.05466196, 0.09664924],
#          dtype=float32),
#    array([0.12791343, 0.07597938, 0.26133427, 0.00975723, 0.7375855 ],
#          dtype=float32),
#    array([0.9712895 , 0.10505997, 0.05270773, 0.01519862, 0.07646042],
#          dtype=float32),
#    array([0.24226828, 0.04779089, 0.18502901, 0.00502275, 0.66033244],
#          dtype=float32),
#    array([0.9428877 , 0.06723408, 0.09676124, 0.02334413, 0.20096733],
#          dtype=float32),
#    array([0.38785353, 0.85075134, 0.08647694, 0.63346636, 0.01787693],
#          dtype=float32),
#    array([0.03075961, 0.01547084, 0.9201666 , 0.01283465, 0.00493877],
#          dtype=float32),
#    array([0.06076841, 0.09927007, 0.7200445 , 0.01821652, 0.01118711],
#          dtype=float32),
#    array([0.1231479 , 0.05976442, 0.16786943, 0.01688254, 0.90945804],
#          dtype=float32),
#    array([0.97580147, 0.39201263, 0.03181843, 0.0275378 , 0.0682678 ],
#          dtype=float32),
#    array([0.06703731, 0.31547534, 0.20914853, 0.01411412, 0.31272337],
#          dtype=float32),
#    array([0.46368504, 0.04271656, 0.11562099, 0.00663365, 0.76933557],
#          dtype=float32),
#    array([0.01647034, 0.01144475, 0.85873616, 0.01518859, 0.08291404],
#          dtype=float32),
#    array([0.10001264, 0.04774604, 0.4878185 , 0.09768444, 0.24539082],
#          dtype=float32),
#    array([0.02057362, 0.8331506 , 0.08703784, 0.514665  , 0.02186181],
#          dtype=float32),
#    array([0.02910301, 0.7396821 , 0.19155692, 0.10546027, 0.00619124],
#          dtype=float32),
#    array([0.10023262, 0.03416868, 0.8243421 , 0.01592233, 0.00613878],
#          dtype=float32),
#    array([0.02204952, 0.08267963, 0.85749596, 0.01517901, 0.00374287],
#          dtype=float32),
#    array([0.31797045, 0.2505629 , 0.38676542, 0.04292285, 0.04764194],
#          dtype=float32),
#    array([0.8724302 , 0.01658531, 0.25823158, 0.01768632, 0.02937715],
#          dtype=float32),
#    array([0.05600429, 0.02923426, 0.825878  , 0.07540039, 0.00330363],
#          dtype=float32)]),
#  (['Such a good idea and a great price for as many toppings as you want',
#    'My pizzas are always delicious',
#    'filling',
#    'and fast',
#    "It ' s also always nice to get a draft beer",
#    'I recommend this place to anyone looking for something fast and delicious'],
#   [array([0.11564638, 0.06341081, 0.04766837, 0.02364136, 0.982904  ],
#          dtype=float32),
#    array([0.01110891, 0.22004972, 0.69735646, 0.00761562, 0.06300978],
#          dtype=float32),
#    array([0.01079207, 0.04963774, 0.90884215, 0.02056732, 0.00748941],
#          dtype=float32),
#    array([0.05280587, 0.2851971 , 0.50343233, 0.07316025, 0.00724761],
#          dtype=float32),
#    array([0.01500419, 0.01465134, 0.57692945, 0.00875087, 0.5895094 ],
#          dtype=float32),
#    array([0.93663836, 0.07139405, 0.06853665, 0.015834  , 0.38047153],
#          dtype=float32)]),
#  (['Fast',
# ...
#    'I hear management is a major issue and I saw it for myself to be true',
#    'The manager Bobby has an attitude and scolds his employees in front of customers',
#    'POOR QUALITY',
#    'I tried calling corporate and the franchise owner but have had no luck',
#    'If I could give this location 0 stars I would'],
#   [array([0.56791866, 0.7774123 , 0.03157926, 0.19577296, 0.03840467],
#          dtype=float32),
#    array([0.09829435, 0.4182485 , 0.3190934 , 0.0399699 , 0.03027794],
#          dtype=float32),
#    array([0.96142775, 0.68475556, 0.03918197, 0.05563611, 0.04273633],
#          dtype=float32),
#    array([0.03761825, 0.22543252, 0.83044404, 0.01762058, 0.02167396],
#          dtype=float32),
#    array([0.00655128, 0.02666407, 0.87712216, 0.02271607, 0.02600742],
#          dtype=float32),
#    array([0.97786635, 0.08175785, 0.05389924, 0.01497508, 0.0996098 ],
#          dtype=float32),
#    array([0.9693771 , 0.06643207, 0.05271506, 0.04773905, 0.32768843],
#          dtype=float32)]),
#  (['I have gone to this place various times',
#    'never had a problem',
#    'The staff is always nice and attentive',
#    'Last time I was there the manager bobby got upset bc of how much toppings I put on my pizza',
#    'I told him it was under done and he got an attitude with me',
#    'I later spoke with Jay and she apologized for the pizza being underdone',
#    'And she just threw it back into the oven',
#    "I wasn ' t even asking bobby for a new one",
#    'Every time I go in Jay and Justin are good on customer service',
#    'Unlike bobby',
#    "he ' s always stressing out and cussing under his breath",
#    'I will be returning thou amazing pizza UNLIMITED TOPPINGS worth it'],
#   [array([0.96101856, 0.2148073 , 0.04664515, 0.01543406, 0.08318993],
#          dtype=float32),
#    array([0.1998674 , 0.02326113, 0.69871724, 0.02362036, 0.01107614],
#          dtype=float32),
#    array([0.08746102, 0.8592828 , 0.16226393, 0.00881943, 0.01575006],
#          dtype=float32),
#    array([0.9763407 , 0.37067127, 0.02955809, 0.07061999, 0.10852522],
#          dtype=float32),
#    array([0.9535972 , 0.26883107, 0.07164124, 0.0775655 , 0.09203231],
#          dtype=float32),
#    array([0.961062  , 0.0576001 , 0.08649027, 0.02305684, 0.15912862],
#          dtype=float32),
#    array([0.03250998, 0.92742383, 0.1742336 , 0.05795226, 0.0070477 ],
#          dtype=float32),
#    array([0.97820497, 0.08853341, 0.05910074, 0.01143031, 0.10459029],
#          dtype=float32),
#    array([0.94744325, 0.28593695, 0.07661308, 0.03419391, 0.09539854],
#          dtype=float32),
#    array([0.01204188, 0.152426  , 0.38627496, 0.02377079, 0.38147277],
#          dtype=float32),
#    array([0.03955849, 0.8901833 , 0.25175333, 0.02916597, 0.06596379],
#          dtype=float32),
#    array([0.96303153, 0.2015591 , 0.05530224, 0.02756215, 0.04909752],
#          dtype=float32)]),
#  (['Came here the other night and it took 25 minutes to order',
#    "Only 3 other parties before us and they had 11 staff working so I ' m not sure what took so long",
#    'Possibly the online orders',
#    'but still',
#    'the person making our pizzas took forever to put on each topping',
#    'Food was good',
#    'but just disappointed that it took so long'],
#   [array([0.01266311, 0.01026258, 0.95447123, 0.0074624 , 0.01190987],
#          dtype=float32),
#    array([0.96502763, 0.3859479 , 0.03319253, 0.0369796 , 0.06916586],
#          dtype=float32),
#    array([0.00203796, 0.00990022, 0.8959235 , 0.00470797, 0.07406522],
#          dtype=float32),
#    array([0.05133766, 0.37007585, 0.45975187, 0.04303722, 0.00556595],
#          dtype=float32),
#    array([0.04306594, 0.93775624, 0.10373349, 0.02620934, 0.01756097],
#          dtype=float32),
#    array([0.09755604, 0.13044855, 0.36440665, 0.6178596 , 0.01041778],
#          dtype=float32),
#    array([0.91307724, 0.2760877 , 0.13653974, 0.14445584, 0.03675758],
#          dtype=float32)]),
#  (['Not many options in town for vegan pizzas but this place is nice',
#    'Vegan cheese',
#    'vegan chicken and soyrizo',
#    'Such a great spot',
#    'Lots of hand sanitizer',
#    'indoor dining when I went but very safe with the tables properly distanced',
#    'One of my favorite places to eat in town'],
#   [array([0.0214374 , 0.91257715, 0.15725099, 0.03711049, 0.00863651],
#          dtype=float32),
#    array([0.03613632, 0.03040919, 0.8066259 , 0.03919455, 0.01281456],
#          dtype=float32),
#    array([0.20282012, 0.06903641, 0.613346  , 0.05240854, 0.01578171],
#          dtype=float32),
#    array([0.08144598, 0.04462414, 0.16097969, 0.00768524, 0.81980574],
#          dtype=float32),
#    array([0.03592585, 0.03414391, 0.27840233, 0.00837343, 0.6934313 ],
#          dtype=float32),
#    array([0.7884809 , 0.01868912, 0.23124403, 0.01195982, 0.21206157],
#          dtype=float32),
#    array([0.01080128, 0.32066438, 0.6854053 , 0.01551527, 0.05441698],
#          dtype=float32)]),
#  (['Tasty and fresh pizza',
#    'Very cool process',
#    'U can add whatever toppings you want',
#    'Blew me away on how quick it cooked',
#    'Like 2 minutes',
#    'Nice staff'],
#   [array([0.661573  , 0.10393435, 0.2726359 , 0.02199483, 0.03277881],
#          dtype=float32),
#    array([0.0746952 , 0.01443291, 0.52218604, 0.01039673, 0.3425847 ],
#          dtype=float32),
#    array([0.9719014 , 0.11482237, 0.06388404, 0.02040651, 0.14118783],
#          dtype=float32),
#    array([0.01301389, 0.9535259 , 0.12064616, 0.02265588, 0.01145891],
#          dtype=float32),
#    array([0.07631635, 0.05134208, 0.63964736, 0.01798917, 0.02673253],
#          dtype=float32),
#    array([0.03355808, 0.8507422 , 0.10658146, 0.05313838, 0.00768569],
#          dtype=float32)]),
#  (['Loooove coming here',
#    'I get the allergy GF crust build your own pizza',
#    'The staff is really nice & they are pretty fast at cooking your pizza',
#    'I checked their ingredients online for the sauce & crust - no additives'],
#   [array([0.06832448, 0.42452452, 0.312241  , 0.23572296, 0.00421372],
#          dtype=float32),
#    array([0.82401574, 0.45986426, 0.0335534 , 0.04331565, 0.44204986],
#          dtype=float32),
#    array([0.40226153, 0.9338169 , 0.05496565, 0.02238775, 0.01609964],
#          dtype=float32),
#    array([0.95467144, 0.06168212, 0.05695302, 0.06580079, 0.34528306],
#          dtype=float32)]),
#  (['Had a BOGO coupon',
#    "figured it couldn ' t hurt to try it out",
#    'most impressed at the new State Steet location',
#    "Staff was super friendly and we ' re very good at guiding you through the process of choosing a ton of different toppings / add ons",
#    'Got the Green Stripe and Art Lover',
#    'you can add any additional toppings with no extra charge',
#    'you can also add to their already listed signature pizzas',
#    'The line moved very quickly',
#    'It cooked so fast',
#    'it was hot and very flavorful',
#    'Very delish',
#    'To go boxes are ready on a shelf if neeed',
#    'a ton of Parm',
#    'red peppers and basil shakers available',
#    'The selection of lemonades looked great',
#    'Seating is a little cramped and has a weird layout and they should add one more trash receptacle towards the back',
#    'so people could have easier access',
#    'Customer service was def 2 up',
#    'we were checked in on twice',
#    'Would definitely go back',
#    'For a personal pizza for $ 8',
#    '25',
#    "you can ' t go wrong",
#    'Convenient',
#    'good parking',
#    'good price',
#    'filling and tasty',
#    'definitely recommend'],
#   [array([0.01837813, 0.03463741, 0.68571377, 0.01107176, 0.17744988],
#          dtype=float32),
#    array([0.02274196, 0.12417923, 0.8424278 , 0.00600087, 0.00982474],
#          dtype=float32),
#    array([0.07528642, 0.7206124 , 0.0411147 , 0.13354127, 0.813275  ],
#          dtype=float32),
#    array([0.4687634 , 0.9446378 , 0.05942578, 0.01955622, 0.0267039 ],
#          dtype=float32),
#    array([0.06937435, 0.2913554 , 0.6685534 , 0.02538287, 0.00379016],
#          dtype=float32),
#    array([0.709712 , 0.319453 , 0.0425173, 0.0574629, 0.6055608],
#          dtype=float32),
#    array([0.25487828, 0.18285756, 0.08059803, 0.01750094, 0.8806578 ],
#          dtype=float32),
#    array([0.00886415, 0.02379692, 0.8609309 , 0.00934905, 0.06433807],
#          dtype=float32),
#    array([0.34569302, 0.6112203 , 0.19158071, 0.01078193, 0.00805348],
#          dtype=float32),
#    array([0.05426761, 0.02426456, 0.6011632 , 0.3825592 , 0.13078666],
#          dtype=float32),
#    array([0.01708042, 0.6383808 , 0.29966792, 0.03507689, 0.01068027],
#          dtype=float32),
#    array([0.4631595 , 0.44885573, 0.26154828, 0.13837041, 0.03680044],
#          dtype=float32),
#    array([0.00957602, 0.02135183, 0.8500904 , 0.00851412, 0.09971149],
#          dtype=float32),
#    array([0.69525707, 0.66178024, 0.11049843, 0.08988884, 0.06328129],
#          dtype=float32),
#    array([0.0168064 , 0.02959846, 0.89468765, 0.00858839, 0.03182023],
#          dtype=float32),
#    array([0.6548493 , 0.8886457 , 0.05948498, 0.04286683, 0.24032652],
#          dtype=float32),
#    array([0.170575  , 0.00656573, 0.33999944, 0.03699228, 0.62472355],
#          dtype=float32),
#    array([0.03063082, 0.50807035, 0.09214585, 0.61904883, 0.09984425],
#          dtype=float32),
#    array([0.02366368, 0.92137444, 0.07828951, 0.06484456, 0.02827984],
#          dtype=float32),
#    array([0.15829523, 0.22334662, 0.56722367, 0.05813778, 0.00313257],
#          dtype=float32),
#    array([0.01017707, 0.07285647, 0.7541431 , 0.01688585, 0.21659137],
#          dtype=float32),
#    array([0.03319397, 0.01084955, 0.9049518 , 0.00689496, 0.01772639],
#          dtype=float32),
#    array([0.22330771, 0.05145648, 0.57478225, 0.00207142, 0.04474602],
#          dtype=float32),
#    array([0.08832213, 0.0240786 , 0.8841591 , 0.01406022, 0.00607657],
#          dtype=float32),
#    array([0.04122724, 0.01521147, 0.9021994 , 0.01545888, 0.00617838],
#          dtype=float32),
#    array([0.0746315 , 0.01597933, 0.8954558 , 0.01663498, 0.00335385],
#          dtype=float32),
#    array([0.04339856, 0.4454801 , 0.29535744, 0.02062163, 0.06234206],
#          dtype=float32),
#    array([0.05590104, 0.01290632, 0.83687544, 0.08940399, 0.00477297],
#          dtype=float32)]),
#  (['Customize your pizza for only $ 9',
#    '00 Quick',
#    'simple',
#    'good',
#    'Everything is very fresh and there are a lot of topping options',
#    'though none of them are organic',
#    'It is the best affordable option in this area of SB'],
#   [array([0.01699663, 0.90026295, 0.2234641 , 0.01152536, 0.0537735 ],
#          dtype=float32),
#    array([0.02653873, 0.8611484 , 0.11065971, 0.12007985, 0.00763589],
#          dtype=float32),
#    array([0.06680077, 0.04519381, 0.5653603 , 0.03028527, 0.09625991],
#          dtype=float32),
#    array([0.03006027, 0.01963099, 0.9147942 , 0.0091259 , 0.00725178],
#          dtype=float32),
#    array([0.672817  , 0.31925243, 0.17867719, 0.02181415, 0.06883943],
#          dtype=float32),
#    array([0.11597548, 0.8174516 , 0.03784299, 0.34554178, 0.00957505],
#          dtype=float32),
#    array([0.08703396, 0.6092975 , 0.2476081 , 0.00408872, 0.03631165],
#          dtype=float32)]),
#  (['First off',
#    "there ' s like 13 kids working and doing absolutely nothing",
#    'Literally running into each other laughing and joking',
#    'I got to the counter and ordered my pizza I asked the kid if the cauliflower crust was any good',
#    'he said " dude I don \' t know',
#    'some people like it " It Would be wise for blaze Pizza to have their employees at least try some of their menu options so they can give positive or negative feedback to the customer',
#    'It would help the customer with his or her choices',
#    'I ordered the veg out',
#    'Big mistake',
#    "There ' s literally three vegetables on it Gorgonzola and a ton of marinara",
#    'The combination of broccoli',
#    'Gorgonzola and red onion taste like fart',
#    'I was very disappointed because I have had this pizza before at a Blaze in Los Angeles and it was choice',
#    'This kid piled it on like he was at Subway sandwich',
#    'Lol',
#    'Why do you have so many employees',
#    "Sorry for the bad review i ' m only trying to help",
#    'The kid at the register was totally cool',
#    "He was polite and intelligent I don ' t know his name wish I did because you guys should make him manager"],
#   [array([0.04893134, 0.14597182, 0.55100584, 0.13013723, 0.01750796],
#          dtype=float32),
#    array([0.36443877, 0.9487375 , 0.06998093, 0.0721995 , 0.06858293],
#          dtype=float32),
#    array([0.00663175, 0.3561659 , 0.77800417, 0.02125314, 0.01192845],
#          dtype=float32),
#    array([0.96873116, 0.24547088, 0.03886291, 0.05676389, 0.12892082],
#          dtype=float32),
#    array([0.9038783 , 0.4392501 , 0.0886878 , 0.02432431, 0.03177748],
#          dtype=float32),
#    array([0.96374756, 0.08990739, 0.05577892, 0.02086377, 0.35864022],
#          dtype=float32),
#    array([0.21992376, 0.249661  , 0.37367302, 0.12257478, 0.04258689],
#          dtype=float32),
#    array([0.93628114, 0.09075836, 0.07282583, 0.00772221, 0.1775745 ],
#          dtype=float32),
#    array([0.05419207, 0.01033987, 0.79583037, 0.01061752, 0.05767538],
#          dtype=float32),
#    array([0.4053551 , 0.43148807, 0.37866366, 0.02307072, 0.07487596],
#          dtype=float32),
#    array([0.02424695, 0.02296535, 0.17816603, 0.01039945, 0.84769696],
#          dtype=float32),
#    array([0.01552021, 0.9303154 , 0.16580683, 0.03778433, 0.07857413],
#          dtype=float32),
#    array([0.9764173 , 0.27478072, 0.03175921, 0.0466474 , 0.08929359],
#          dtype=float32),
#    array([0.4132158 , 0.778899  , 0.19596659, 0.11734641, 0.01532276],
#          dtype=float32),
#    array([0.05758378, 0.02035347, 0.8846539 , 0.02284965, 0.00491559],
#          dtype=float32),
#    array([0.5961931 , 0.01023049, 0.21404532, 0.0165924 , 0.47076344],
#          dtype=float32),
#    array([0.3067092 , 0.01563644, 0.37659   , 0.00370799, 0.54485905],
#          dtype=float32),
#    array([0.09449742, 0.05821631, 0.55898   , 0.30079076, 0.06407408],
#          dtype=float32),
#    array([0.966002  , 0.27425867, 0.0634121 , 0.04510493, 0.06041722],
#          dtype=float32)]),
#  (['I won a free pizza through Instagram',
#    'This place is set up like an assembly line with all the toppings and sauces behind a glass wall you choose from',
#    'You get to select everything',
#    'crust',
#    'sauce',
#    'toppings',
#    'This is great',
#    "They were busy when I walked in to make my order of four pizzas - all different crusts & toppings and their work pace didn ' t stop",
#    'the employees flow so well',
#    'the order was made so quickly even tho it was busy',
#    'so impressed',
#    'They have a giant pizza oven that fits several pizzas',
#    'You can get sides like jalapeno and ranch',
#    'I enjoyed the pizzas I ordered and the service was friendly and fast'],
#   [array([0.821853  , 0.02095757, 0.16576764, 0.04452413, 0.1979349 ],
#          dtype=float32),
#    array([0.7387999 , 0.8722704 , 0.03732336, 0.01299848, 0.02047746],
#          dtype=float32),
#    array([0.00800404, 0.03342619, 0.9314771 , 0.00622561, 0.00912207],
#          dtype=float32),
#    array([0.03396348, 0.05159869, 0.7822126 , 0.20215775, 0.00207503],
#          dtype=float32),
#    array([0.06546796, 0.03062664, 0.8585625 , 0.02255115, 0.00447625],
#          dtype=float32),
#    array([0.02096563, 0.0255962 , 0.90557003, 0.01543399, 0.00710639],
#          dtype=float32),
#    array([0.13452208, 0.8794396 , 0.05848164, 0.02216641, 0.00717819],
#          dtype=float32),
#    array([0.70951676, 0.23556444, 0.04620194, 0.04713171, 0.79932123],
#          dtype=float32),
#    array([0.48376802, 0.01165565, 0.57389235, 0.01423844, 0.02404358],
#          dtype=float32),
#    array([0.8616298 , 0.01906716, 0.15810302, 0.14586984, 0.27653465],
#          dtype=float32),
#    array([0.7700104 , 0.08950895, 0.21161394, 0.00827281, 0.05557887],
#          dtype=float32),
#    array([0.0576399 , 0.04550048, 0.08969547, 0.00853979, 0.9436698 ],
#          dtype=float32),
#    array([0.295752  , 0.35407847, 0.09722689, 0.30169907, 0.38640177],
#          dtype=float32),
#    array([0.974987  , 0.08004142, 0.0521356 , 0.02714587, 0.22988956],
#          dtype=float32)])]

# %% [markdown]
# ### Map text, according to model's predictions, into an array that groups by topic

# %%
# Mapping of index to topics
topics = ['service', 'food', 'anecdotes/miscellaneous', 'price', 'ambience']

# Dictionary to hold the tokenized texts classified under each label
tokens_for_labels = {topic: [] for topic in topics}

# Threshold for classification
threshold = 0.80

# Iterate through all_predictions
for segment_texts, segment_predictions in all_predictions:
    for text, prediction in zip(segment_texts, segment_predictions):
        # Iterate through each probability in prediction
        for index, prob in enumerate(prediction):
            # Check if probability exceeds the threshold
            if prob > threshold:
                # Append the text to the corresponding topic in the dictionary
                tokens_for_labels[topics[index]].append(text)

# %%
# Check
tokens_for_labels
# Out:
# {'service': ['I came on the busiest day of the year',
#   'I did a build your own pizza with the following : Sauce : Red Sauce Cheese : Shredded mozzarella with feta sprinkled around Meat : Smoked Ham',
#   '" I stopped by last night with a friend to take advantage of their Pi Day deal',
#   'I just got this vibe that they minimize their ingredients',
#   "Thinnest layer of sauce I ' ve seen on a pizza",
#   "but there are other places I ' d rather go",
#   'I love that you can make your own pizza the way you want',
#   'I love me some personalized pizza and sometimes franchise establishments become jaded',
#   "So close to my house which means it ' s so dangerous",
#   'hardy pizza and salad',
#   'We are definitely returning here because they also have gluten - free pizza crust available and daiya cheese alternative for my lactose and gluten free children',
#   'I called the State Street location at 6 : 40pm last night and placed my order for 1 pizza',
#   'so the order definitely came through',
#   "I showed up 25 minutes later just after 7pm to be told by the worker at the register that he didn ' t know what I was talking about",
#   "He reluctantly asked the worker at the front of the line who writes the names on the papers and was told my pizza hadn ' t been made yet",
#   'They asked me to wait another 15 minutes and when I said that I was unhappy',
#   'I have gotten pizza to go here several times',
#   'The other issue is that they use the same couple of roller cutters to cut all the pizzas into slices so sometimes I have tasted BBQ sauce on my pizza because the pizza they cut prior to mine had BBQ sauce on it and it transfers to my pizza',
#   'I said " hello " and barely got a " hi " back',
#   "I thanked the girl boxing up my pizza and she didn ' t even respond or even look in my direction",
#   "I really wish they didn ' t do this because thermal paper could contain BPA or other harmful chemicals",
#   "We ' ve ordered take - out one time and have been hesitant to do so again because of this",
#   "I ' m a Deep Dish Chicago Style pizza lover n they did a good job",
#   'I especially love their selection of drinks',
#   ') but I personally feel that what they do have ( a few kinds of soda and different flavors of very nice Aqua Fresca ) goes along PERFECTLY with their style - both taste and atmosphere',
#   "If you haven ' t tried this place yet",
#   "I promise you ' ll love it : )",
#   "Made sure to ask me questions regarding how I ' d like my pizza made",
#   'As I left they aslo said good bye and to have a nice day which is always nice to hear',
#   'Overall I think the staff went out of their way to make sure I had a satisfactory experience',
#   'Love creating my own w / unlimited toppings for one low price',
#   'Have so many options and did I mention that they even have VEGAN options',
#   "I ' ve been going to Blaze in Sacramento for years and am so glad to now have one local",
#   'I definitely recommend Blaze Pizza',
#   'Last night I went to order a pizza after work around 8 : 30',
#   'I have visited this specific location many times and have had good service and bad service',
#   "Last night was the worst service I ' ve ever had",
#   'When I first walked up to the building there were a group of kids smoking a joint right outside the door',
#   'I ordered and my pizza was made',
#   "I left with my pizza after they finally figured out who ' s belonged to whom",
#   'While I was eating my pizza',
#   'so I threw it away and walked out',
#   'and like I mentioned',
#   'I understand having fun at work',
#   'If you \' re trying to choose a " build your own " pizza place ( Persona',
#   "I ' m in LOVE",
#   'Cooks in something like 3 min - so so tasty',
#   'So bummed',
#   'I tried to call when we looked at the order and it just goes to voicemail',
#   'I have sent people over but this was horrible',
#   'Really disappointed that I couldnt call in',
#   "It ' s our first time in blaze in Santa Barbara in this location all the employees are super nice the lady who helped us for name is Haley very nice lady very helpful and the manager Bobby he was nice guy also we really high recommended this place pizza location very nice and the pizza is excellent like always",
#   'Greasy pizza with way too much salt and garlic ( the green stripe ) and The Caesar salad had no flavor with soggy stale textured croutons Second try and both times very disappointed',
#   "I can ' t go back there",
#   'I enjoyed being able to build my own pizza and the toppings they had',
#   'I also liked the selection of drinks they had and salad options',
#   'I feel like Pizza Rev has more topping choices',
#   'I also found it interesting that the meat lovers pizza on the menu only had two meats on it',
#   "The tables are family style and there isn ' t much space but it ' s cozy",
#   'I have been very disappointed with this location recently',
#   "I don ' t like writing reviews but today just did it for me",
#   'When she calls my order to be picked up I say thank you and she just looks at me and cuts the next pizza which was my sisters',
#   "This restaurant is much better than the previous establishment and I ' m glad they are here",
#   "I ' m not a fan of fast food in general",
#   'The " assembly line " style of fast food is taking over and pizza seems to be one of the more popular options',
#   'If you really add up the toppings it can really be a decent pizza and most people would end up saving a bit to take home',
#   'The few times I have visit',
#   "I didn ' t wait long for my pizza to get done",
#   'you have a choice between one of their custom made pies or " build your own "',
#   'I opted for the latter with just pepperoni and mushroom',
#   'I think if you want yours loaded',
#   'From the time I placed my order to the time out the door was about 15 minutes',
#   'although my box felt pretty light when I received it and I almost had to make sure that it was in there',
#   'Would I return',
#   'I recommend this place to anyone looking for something fast and delicious',
#   'She could have said " I \' ll check in the back " but apparently she didn \' t care',
#   'Whatever you want on your thin crust pizza for $ 9',
#   'I will be back',
#   'I love making my own pizza',
#   "It ' s so fun to be able to choose as many toppings as you want for one price",
#   'I had the Link In ( sausage',
#   'I asked for Parmesan cheese and he just threw it at me',
#   'I have been here before and he had the same attitude',
#   'especially if you eat in house cause the crust is still crispy',
#   'Love this place love the food',
#   'She asked me what I wanted on my pizza and was yelling towards me to get my order',
#   'When I asked her to put arugula on top of my pizza after it was fired she rolled her eyes and turned away from me',
#   'I always encounter her when I come here and I have tried to ignore her attitude but today she was over the top',
#   'I am a returning customer',
#   'I asked for a " fresh salad " because there was just a handful left in the tray n they acted like it was an inconvenience to give me what I wanted',
#   'They did what I asked BUT very grudgingly n gave the look of disgust like it was above their job duty',
#   'I am debating a return trip',
#   'I came in here last minute starving one day ( and have since returned ) with no other food options',
#   'I usually avoid these new individual pizza places because they are not very good but I was suprised here',
#   'prices are typical and best of all the pizza was awesome',
#   'Art Lover is our new favorite with ricotta and dollops of fresh red sauce',
#   'My family and I love this place',
#   "It ' s great because I ' m vegan and they have vegan choices",
#   'I chose pesto as a base and loaded up on veggies',
#   'I had plenty of pizza left over for later',
#   'but upon arrival I waited in line for 25 minutes when there were only 5 people ahead of me',
#   'I love their thin crust',
#   'We like the fact that they are using more environmentally friendly plant based straws and cups and lids',
#   'I dunno but easy this',
#   "JRB I ' m writing more cause yep said it was too short",
#   "I ' m speechless cause I ' m currently eating this freaking good pie",
#   "I ' m out",
#   'Love this new place',
#   'We live only like two minutes away so that could not have been the cause for it being soggy',
#   'I will only get it when we are very hungry and need something cheep and quick',
#   "honestly I ' d rather have Carl ' s Jr",
#   'I loaded it up supreme style',
#   'but I see the owner there all the time trying to get good help',
#   'I have been charged four times for the same ( mediocre ) pizza',
#   'I said I had already paid',
#   "but the kid at the register insisted I hadn ' t",
#   '( The guy who I paid initially was nowhere to be found',
#   'The same guy asked me if I had paid yet',
#   "I ' m honest so I told him that I hadn ' t and gave him my credit card",
#   "I didn ' t have a receipt to say that he was wrong and took him at his word",
#   'I called my bank to dispute the second charge',
#   "I ' m done",
#   "but I figured I ' d call them to give them a heads - up that my bank was going to reverse one of the charges and not put through the two additional pending charges",
#   'Like I said',
#   'What I love most are the fresh ingredients',
#   'I also love the thin crispy flavorful crust',
#   'I love this place',
#   "She always ensures I ' m being taken care of and makes my day",
#   'I found this place out of pure hunger',
#   "I would have given it 5 stars if the 1 out of 3 of our pizzas wasn ' t burnt",
#   'I add a touch extra sauce because it is perfectly spiced',
#   'I have never had a bland Pizza from Blaze',
#   "I ' m on my way to pick up my order now",
#   "Let ' s hope they are all so well run as the one on upper State",
#   '- Reviewed by The Pizza Princess ( daughter of a past owner of 14 Pizza stores in the east',
#   'Just saying that I am once again Wowed with awesome service',
#   "I ' ve been here a few times now and found the pizza to be delicious",
#   'I got the bbq chicken and would recommend it',
#   'This is the kind of business I like to visit',
#   'I ordered the " high rise " crust',
#   'I don \' t understand why you have to pay $ 2 extra for " high rise',
#   '" so that \' s kind of annoying',
#   'I got the BBQ chicken pizza and added smoked ham',
#   'and I ate half my pizza before I realized it was missing',
#   'They had no problem adding it when I went up to the counter and let them know that it was supposed to be on there',
#   "The lady didn ' t speak English either so very difficult to work with them",
#   'Love this place for the fast pizza and custom orders',
#   'I really enjoy going to places that cater to your desire and go above and beyond',
#   'I think if a customer requests " a lot " of one item it would be somewhat rediculous for the server to get tablespoon worth of topping and ask is that ok',
#   'I only usually choose 3 toppings',
#   "It ' s kind of lame when I have to ask 4 times to add my favorite topping",
#   'Here are my phrases that I used to let the server know I mean business',
#   'I love pepperoni',
#   'please cover the whole pizza Please add more to cover the gaps in the pizza The pepperoni shrinks so please overlap the pepperoni ( After the pizza goes to the end for final roasted garlic ) Would you please go back and add more pepperoni Should I be more excited and ask for a specific number of pepperoni',
#   "Jk I wouldn ' t do that",
#   "it ' s not like I ' m asking for 10 toppings and making a mound filled pizza",
#   "let ' s just say another server got my wife ' s order perfect",
#   "He added all the toppings without making it equally spaced and even had to tell my server to make sure the pizza sauce covered the whole pizza crust so it wouldn ' t burn",
#   "and I ' ll give ' em that",
#   "In the end I settled for a pizza with extra toppings I didn ' t really want - to cover up areas where the pepperoni was lacking lol",
#   'I get to choose my toppings for a very decent price',
#   'I had dinner here last night',
#   'As soon as I walked in the supervisor yelled at his employees in front of the whole restaurant for running out of pre folded to go boxes or something',
#   "Blaze is probably best if you ' re just looking for a solid meal that tastes pretty good",
#   "I don ' t see myself returning to eat here in the future",
#   "I ' m not usually a pizza person",
#   'because I like THIN crust and very little cheese',
#   "I ' ve been there several times",
#   'We had an issue with Postmates and had to pick up but the manager was very understanding on the phone ( wish I remembered his name ) and Diego was there when we picked it up and was so helpful and nice',
#   'I asked " Thania " for a bottle opener and she replied SARCASTICALLY " open it with your mouth " and I said excuse me',
#   "I was so confused why someone I ' ve never seen replied to me in such discussing way",
#   '" And I said look I don \' t know why your responding to me this way I want my money back for the knots don \' t make them any more',
#   'And if you have one why are you eating here',
#   '" And I said look you are not The owner and respect my meal and remove your self from our table',
#   'You are so unprofessional',
#   'I told her I would call the general manager and she said go ahead his phone is always off',
#   'And I did and she was right phone is off',
#   'I sent an email',
#   "and sad that I can ' t even go have lunch with my family at this place with such disrespectful blaze workers",
#   'If i had been the one to pick it up I would have sent it back',
#   'Not a place I would return to',
#   'but considering they sent me a two - for - one coupon and another free coupon the price is right',
#   'I got 2 signature pizzas and noticed they were super light on the toppings',
#   'So I think the better way to go would be build - your - own',
#   "I ' m sure it wouldn ' t be skimpy if you chose a bunch of options",
#   'Last night I went to order a pizza after work around 8 : 30',
#   'I have visited this specific location many times and have had good service and bad service',
#   "Last night was the worst service I ' ve ever had",
#   'When I first walked up to the building there were a group of kids smoking a joint right outside the door',
#   'I ordered and my pizza was made',
#   "I left with my pizza after they finally figured out who ' s belonged to whom",
#   'While I was eating my pizza',
#   'so I threw it away and walked out',
#   'and like I mentioned',
#   'I understand having fun at work',
#   'I will have to say I was impressed',
#   'I got my pizza made and ready to go faster than I knew what was happening',
#   'I love garlic',
#   'I cook with garlic',
#   'I use raw garlic sometimes',
#   'When I mentioned it to a friend I was with later in the afternoon',
#   '" Fortunately I was home alone for the evening',
#   "I don ' t know whether the regular tomato sauce would have been a much different experience",
#   'I had had nothing but great experiences at Blaze',
#   'I was the only person in line and the pizza maker stated that he had to quickly make a pizza for an online order and he would be right with me',
#   'Then to new customers came in behind me and the same worker indicated he would be right with them',
#   "I ' m heading over to chipotle",
#   'I had high expectations for Blaze',
#   'I ordered a pizza and explained my food allergies and my pizza was cut with the same pizza cutter used on the rest of the pizzas',
#   'I was wondering how I would order a pizza on a production line - style system',
#   'I like how they have the Take Two deal where you can have half a pizza and salad',
#   'I got the Arugula and Berry Salad which had so many fresh strawberries and blueberries',
#   "i was surprised they didn ' t charge extra for it",
#   'I also like how they call your name',
#   'I called the driver',
#   'At 9 I got thru to Blaze',
#   "I ' m REALLY disappointed but no longer angry",
#   'I will tell my friends about this experience',
#   "I ' m sure",
#   "I came for the coupon but I ' ll come back for the pizza",
#   'the last time was the worst and this will be the last time we will come here',
#   'the person baking the pizzas asked that someone make boxes because he was all out',
#   'don \' t bother preordering because they don \' t make it until you \' re there to " check in " which means stand in line and tell them you have a mobile / online order and still walk through as if you didn \' t pre order',
#   'the drive and getting your pizza will be much faster then this slow place with the worst customer service',
#   "Now if you ' re gonna come stoned to work at least do your job right",
#   'First and last time I try this place',
#   "I ' ve only been to one other blaze but this location was awesome",
#   'I love that you get to choose an unlimited number of toppings for a fixed price of ~ $ 8',
#   'Thank you so much to Nathanial who made our pizzas tonight',
#   'My boyfriend and I are vegan and he changed his gloves and used a different pizza slicer for our pizzas',
#   'So sad to see this place go down hill',
#   'I ordered online and stood there for 45 minutes while they made pizzas for delivery and ignored mine',
#   '( Wife said " no salt " which I repeated while pie was being made',
#   ') I asked for extra crispy and received " mushy " at best',
#   'wifi next door ( " Luna Grill Free Wifi " ) and I think the next time we \' ll just eat there instead',
#   'I have finally found a good pizza spot in sb',
#   'Patxis thin crust is the cost of a full meal out but even a large at $ 32 is only enough for one person bc its so thin and no toppings',
#   'Honesty its amazing and i wish it was closer to my house but i will still be coming back all the time',
#   'I ordered the thicker crust which was delicious',
#   'I was feeling bready today and it hit the spot',
#   'I love how my pizza was full of all the delicious veggies cheeses and toppings i wanted',
#   'I had to go back to get the right one',
#   'I love their pizza especially the cheese and garlic options',
#   "I ' m not generally a fan of chain restaurants taking over what locals used to do so well",
#   "I ' m delighted to be able to order a gluten - free crust and dairy - free cheese",
#   'add another 10 minutes to the stated pick - up time',
#   'Went in to grab some food because I had to work the overnight at my job',
#   "Today was the last time I ' ll go to this place",
#   'Disappointing when wanting to take yourself out to lunch and get berated by the owner when it was his error',
#   'not so much',
#   'I had to roll the slices like a tortilla to eat them as they would not hold the toppings',
#   'I created an old standard',
#   'I \' ll be right with you " just straight ignored us while other customers gathered behind us',
#   "I get with COVID things are a little different but that doesn ' t excuse bad customer service",
#   "If you get a bad pizza here it ' s your own fault",
#   'I like lots of veggies',
#   'Had this pizza delivered last night by Grub Hub and it was DELICIOUS',
#   'I asked for reg sauce reg crust',
#   'Toppings I chose : mushrooms olives peppers red onions vegan mozzarella cheese and pineapple',
#   'I went in late at night around 9 : 10 and waited and waited for my two pizzas',
#   "If I was in there position and someone didn ' t hear there name being called",
#   'I would tell them the pizzas are READY',
#   'dislike the service that I received this one particular night',
#   "If you ' re hammered drunk",
#   'this place is AWESOME a huge hit pizza love great topping options',
#   'First two times I had blaze pizza it was delicious ( dine in once and delivery the second time )',
#   'So yesterday I called in a to - go order thinking it would be a great option for a family and friends gathering',
#   'I guess it just depends on the day',
#   'But I want a reliable pizza shop',
#   'I ordered the salad pizza which they just took off the menu',
#   'The guy making it made me feel as if I had asked for WAY too much and made me feel very uncomfortable talking in a very loud voice',
#   "When I paid for my pizza the manager / owner also cam out and said that they don ' t usually do that and it should have cost me more",
#   'They have done it for me at the other locations and I would never go back to any of their locations',
#   "I don ' t feel like they should have made me feel bad",
#   'And did I mention they gave my pizza away to the wrong person',
#   "Don ' t think I ' ll return anytime in the near future",
#   'I think I will be back again and definitely recommend people to Blaze',
#   'I love their thin thin crust',
#   "The staff is also very knowledgeable about Gluten free and they take every precaution to make sure I don ' t get contaminated",
#   'I am a regular who gets the same order',
#   "and I ' m always VERY satisfied every time",
#   'If you are looking for a good place to get a pizza come here',
#   "In a couple of occasions I ' ve gone there and the person that rings is up has this type of attitude like he is bugged that were there doesn ' t want to help us with our scan code and gets bothered if I ask if we ask for ranch or anything else",
#   'So definitely I need some improvement they need really need to work on their customer service they need to be a little bit more humble and maybe not everyone that goes there gets treated that way but definitely all customers should be treated with kindness and respect',
#   'I heard all these great things about Blaze Pizza and how cheap it is',
#   'I make my own pizzas usually',
#   'but I needed a break',
#   'so thought I would finally give the Blaze app a try and have a couple delivered',
#   'I am vegan',
#   'When I got them',
#   'I was amazed at how small they were',
#   'It is funny because I see a lot of reviews showing customers receiving burnt pizza',
#   'sure I would pay it and eat again',
#   'Now they have a new LARGE SIZE which is a 14 " pizza',
#   'I was so excited for the 3',
#   "I ' ve been a loyal customer despite not having the app and would ' ve liked to enjoy this reward today",
#   "If you ain ' t catching my lingo",
#   "I really love blaze pizza ' s pizza options and how great they are at making your pizza quickly and the ordering process faster",
#   'I usually am really lazy to go in the store and you can readily order from their app on your smart phone and get the pizza quicker than any other food delivery service',
#   "The first time I ' ve been served a pizza unsliced",
#   'I was beyond disappointed',
#   'I understand things are different in the time of COVID',
#   "but if I ' m paying good money for a pizza",
#   'The last two times we ordered through the app we got the wrong pizza and the wrong toppings',
#   'Now it is not worth it unless you watch them make your pizza',
#   'I want to give this place the credit it deserves',
#   "I went in with my wife and baby the other day and while we were familiarizing ourselves with the menu a customer came in screaming that her pizza wasn ' t done properly and made quite de scene",
#   'I hear management is a major issue and I saw it for myself to be true',
#   'I tried calling corporate and the franchise owner but have had no luck',
#   'If I could give this location 0 stars I would',
#   'I have gone to this place various times',
#   'Last time I was there the manager bobby got upset bc of how much toppings I put on my pizza',
#   'I told him it was under done and he got an attitude with me',
#   'I later spoke with Jay and she apologized for the pizza being underdone',
#   "I wasn ' t even asking bobby for a new one",
#   'Every time I go in Jay and Justin are good on customer service',
#   'I will be returning thou amazing pizza UNLIMITED TOPPINGS worth it',
#   "Only 3 other parties before us and they had 11 staff working so I ' m not sure what took so long",
#   'but just disappointed that it took so long',
#   'U can add whatever toppings you want',
#   'I get the allergy GF crust build your own pizza',
#   'I checked their ingredients online for the sauce & crust - no additives',
#   'I got to the counter and ordered my pizza I asked the kid if the cauliflower crust was any good',
#   'he said " dude I don \' t know',
#   'some people like it " It Would be wise for blaze Pizza to have their employees at least try some of their menu options so they can give positive or negative feedback to the customer',
#   'I ordered the veg out',
#   'I was very disappointed because I have had this pizza before at a Blaze in Los Angeles and it was choice',
#   "He was polite and intelligent I don ' t know his name wish I did because you guys should make him manager",
#   'I won a free pizza through Instagram',
#   'the order was made so quickly even tho it was busy',
#   'I enjoyed the pizzas I ordered and the service was friendly and fast'],
#  'food': ['but then again',
#   'I did a build your own pizza with the following : Sauce : Red Sauce Cheese : Shredded mozzarella with feta sprinkled around Meat : Smoked Ham',
#   'Bacon bits',
#   "mushrooms There really wasn ' t much to complain about on the pizza",
#   'but then again',
#   'I just got this vibe that they minimize their ingredients',
#   'An A - OK from me',
#   'This place is amazing',
#   'The girl at the register',
#   'This location is great',
#   'but this one is wonderful',
#   'Plenty of parking in the 5 points plaza',
#   ') - J',
#   'This is a build your own pizza kind of place although they have some default menu',
#   'Easy 4 star',
#   'This is a great place to stop in and get a quick',
#   "There isn ' t anything else on the menu and the air conditioning is too cold for our liking",
#   'but they have really tasty pizza and salads served up quick',
#   'This place is amazing',
#   'This is definitely my new go - to pizza spot',
#   'but decent in a pinch and priced fairly for what you get',
#   'What separates this from really good pizza is the crust',
#   "as the service was always fast and friendly but lately we ' ve noticed a disappointing decline in the customer service",
#   "and the employees looked miserable and didn ' t even acknowledge us",
#   'Great pizza full customizable and awesome quality for not only the meat eater but a vegan delight also',
#   'the staff was awesome they made you feel welcome ps try the brownies',
#   'directly on top of a receipt printed on thermal paper',
#   'which are not healthy to ingest',
#   "We ' ve ordered take - out one time and have been hesitant to do so again because of this",
#   'on 9 / 12 / 17',
#   'Had the " thick " crust Build Your Own last night n again for lunch today',
#   'In my opinion',
#   'but tastes of high quality',
#   "Sure they don ' t have the usual classics that most people have ( i",
#   ') but I personally feel that what they do have ( a few kinds of soda and different flavors of very nice Aqua Fresca ) goes along PERFECTLY with their style - both taste and atmosphere',
#   "Then the Blazer who was actually blazing my pie was also asking me how I ' d like my pizza cooked",
#   "Which surprised me because usually wood fired pizza places don ' t ask me how I ' d like my pizza cooked",
#   'Friendly staff',
#   ': ) )',
#   'the staff is friendly and efficient',
#   'this location has gone downhill fast since opening',
#   'it depends on the staff',
#   'but there was a line of 5 people and no one in the lineup making the pizzas',
#   'Finally one girl came from the back and started on the pizzas',
#   'These two girls were great and helpful',
#   'There was a shorter guy putting the pizzas in the oven',
#   'and then in walks one of this kids smoking the joint outside',
#   'She get behind the counter and starts play hitting the guy putting the pizzas in the oven',
#   "She ended up giving me my salad for free because she couldn ' t find where to input the salad",
#   'I found 5 long black hairs in almost each slice',
#   'but also amazing customer service',
#   'and Blaze ) hands down Blaze takes the cake ( or pie )',
#   ')',
#   'The crust in thin and perfect',
#   'one plain peoperoni',
#   "It ' s our first time in blaze in Santa Barbara in this location all the employees are super nice the lady who helped us for name is Haley very nice lady very helpful and the manager Bobby he was nice guy also we really high recommended this place pizza location very nice and the pizza is excellent like always",
#   'Greasy pizza with way too much salt and garlic ( the green stripe ) and The Caesar salad had no flavor with soggy stale textured croutons Second try and both times very disappointed',
#   'Man this place is bad',
#   "Cheese seemed powdery - like pre - grated cheese from a bag ( not something I ' d usually eat )",
#   'There was one girl working the line who was great and very helpful to the first timers behind us',
#   'She starts to put my order in and walks away',
#   'When she finally comes to finish my transaction she is very short',
#   'She had asked for ranch and glaze on the side and she puts it on the pizza',
#   'She looks like she hates her job',
#   'but they put out a decent and fresh product',
#   "this isn ' t a bad option",
#   'They really do keep the line moving along in a timely manner',
#   'and this was on their second day of operation',
#   'It was kinda soft and a little chewy',
#   "but disappointed by Thania ' s response to the wilted looking Caesar salad",
#   "We said it doesn ' t look fresh ( 3 / 4 of pan empty )",
#   'she said they just put it on line',
#   'Making your own pizza at home would never taste this good',
#   'Cooked my pizza perfect',
#   'all golden brown and cooked throughout',
#   'Ingredients were all in stock and fresh',
#   'Everyone working tonight was smiling and friendly',
#   'This really was a 5 star trip',
#   'trash cans overflowing or garbage in the lot',
#   "It ' s ready to plate in 2",
#   'Got myself a 2 for 1 deal at blaze',
#   'Happened on Blaze on the way to another restaurant and decided to give it a try',
#   'sautéed onions ) and added mushrooms and black olives',
#   'Friendly staff',
#   'This pizza here is tasty and affordable',
#   'Staff is friendly enough',
#   'There is an older man there though that works the oven area',
#   'Music was blah but a lot of places seem to be playing music for the staff and not the patrons',
#   'Nice variety of greens for salads and appears to be well run and quite clean',
#   'First of all she had zero eye contact with me when she took my order she looked annoyed that I even walked in',
#   'She asked me what I wanted on my pizza and was yelling towards me to get my order',
#   'BUT TODAY 11 - 4 at 1320 was the worse service ever',
#   'I ordered a Caesar salad n High Rise Link In pizza',
#   'At this point',
#   'not too greasy and high quality ingredients',
#   'Simple clean food in a nice atmosphere',
#   'They offer gluten - free and dairy - free options',
#   'The service is friendly and quick and there is always a knowledgeable manager on site',
#   'Store manager was so kind about hold my daughters Santa Barbara High School Girls JV Soccer team last dinner',
#   'pizzas are ready shortly after you have paid and found a table',
#   'I was really excited to try blaze',
#   'Staff was really slow and did not seem like they knew what they were doing',
#   'We eat here at least once a week for lunch',
#   'Great staff who are always willing to recommend something new to try',
#   'Thanks Bobby',
#   'Pleasant staff',
#   'We got the meat eater and the white top',
#   'Oh',
#   'This is a great place',
#   'super friendly staff',
#   'Really respectful of my dairy allergy',
#   'This place rocks',
#   'The staff friendly and smiling and eager to help',
#   'Cooked nice and crisp and very fast',
#   'Great pizza Customer service is hit or miss',
#   '( The guy who I paid initially was nowhere to be found',
#   ') So',
#   'the staff are helpful and friendly',
#   'This is my favorite blaze pizza out here in Santa Barbara county',
#   'Danielle is amazing and has great guest service',
#   'and the whole thing is great a pizza made from scratch right before your eyes with FRESH ingredients and awesome thin crust',
#   'We appreciated the friendly staff',
#   'right when we got there the person taking our order made sure each one of our names was spelled correctly',
#   'The pizza was fast ( I mean really fast ) and hot',
#   'But the agua fresca as there are amazingly delicious',
#   'but they re - did another one in lightning speed',
#   'We will visit again soon',
#   'Having grown up in the Pizza business',
#   'I know that the key is in the ingredients',
#   ')',
#   'friendly staff and delicious meal',
#   'thanks Aaron',
#   'which ( to me ) was a normal crust',
#   "We went in and we ' re explained how the menu works",
#   'My daughter and I ordered a half pepperoni pizza and half cheese',
#   'The girl treated us great and we got our pizza is a reasonable amount of time',
#   'They got my entire order wrong and all of my families',
#   'I really enjoy going to places that cater to your desire and go above and beyond',
#   'Just 3 - 4 toppings',
#   'but service was my main focus in this review',
#   'Thanks for the great tasting pizza - looking forward to a better experience in service : )',
#   'The other employees seemed miserable and it was a very unpleasant dining environment',
#   'We could really taste the angst in our food',
#   'will not go here again',
#   'there are definitely better pizza places in the Santa Barbara area',
#   'Wait time seems long but it takes time to cook a pizza so for this type of restaurant there is really nothing to complain about in terms of the wait time',
#   'All in all',
#   'Build your own pizza for about $ 10 including tax',
#   'Dough is really tasty',
#   'Customer service is on point',
#   'Huge plus since most places you feel like you are being rushed',
#   'Blaze is perfect for me',
#   'Excellent price for a build - your - own pizza',
#   'quick service',
#   'friendly staff',
#   'An area that needs attention is definitely cleanliness',
#   'We were here for almost an hour and it was early dinner crowd - - one table plus us',
#   'No one ever bussed or wiped down tables and chairs',
#   'Pretty unappetizing and with plenty of empty ( dirty ) tables and chairs',
#   'Not only was I given my change but was taken from my own hands because the cashier " Thania " was not focused',
#   'She made my 1 transaction into 2 different ones',
#   'Refused to give me my receipts then she finally gave them to me',
#   'Then she finally gave me my receipt missing one',
#   'I told her my order was not complete my 4 knots where missing and she said " and you want me to do what about it',
#   'Minutes passed and as me and my family are eating she comes to the table and tells me all upset " what \' s your problem',
#   'And I did and she was right phone is off',
#   'I left 2 voicemails',
#   'Everything is fresh and great but I hate the wait',
#   'Definitely not worth the price or hype that this chain somehow has',
#   'but considering they sent me a two - for - one coupon and another free coupon the price is right',
#   'I got 2 signature pizzas and noticed they were super light on the toppings',
#   'It was packed and they were all friendly and I was in and out in less than 10 - 15 minutes',
#   'this location has gone downhill fast since opening',
#   'it depends on the staff',
#   'but there was a line of 5 people and no one in the lineup making the pizzas',
#   'Finally one girl came from the back and started on the pizzas',
#   'These two girls were great and helpful',
#   'There was a shorter guy putting the pizzas in the oven',
#   'and then in walks one of this kids smoking the joint outside',
#   'She get behind the counter and starts play hitting the guy putting the pizzas in the oven',
#   "She ended up giving me my salad for free because she couldn ' t find where to input the salad",
#   'I found 5 long black hairs in almost each slice',
#   'No call in orders',
#   "Came in for the first time ( got a coupon in the mail ) and there ' s was a line to the door",
#   'Staff worked great during the rush and the pizza was amazing',
#   'Unlimited topping',
#   'great value ( unlimited toppings',
#   ')',
#   'super friendly staff',
#   'build your own pizza',
#   'is good - I really like Pizza Rev and Pizza Personal in Santa Barbara',
#   'Blaze thin crust is really good - thin and crisp',
#   'spicy tomato on the other',
#   '" Oh',
#   'but I am not going back to find out',
#   'The pizzas were built ( and cooked ) before my eyes and the result was two delicious pies',
#   'If your in need of a quick bite and are craving pizza',
#   'The half pizza is basically a Build Your Own',
#   'we were left very satisfied with our late night dinner',
#   'We ordered at 8 : 01 pm using the kinda - clunky app',
#   'Pizza arrived at 9 : 47',
#   '( expected delivery time 8 : 34 ) I called',
#   'Pizza : soggy and cold',
#   'Salad : Limp ( and not enough wets on the drys )',
#   'This experience ruined our single romantic night together this week',
#   'share it here in detail',
#   'Pick your own toppings',
#   'this has got to be the slowest place ever',
#   "we ' ve been here numerous times hoping that the service gets better but it seems to get worse every single time we go",
#   'there were 7 workers working and 3 people in line',
#   'another was putting them in the oven and another at the register',
#   'they all stood there looking high',
#   'First off the guy baking the pizza was stoned out of his mind the fact that magagment failed to see this is quite shocking to me',
#   'After waiting fo our pizzas for 15 min I assumed the guy had completely forgotten about our pizzas',
#   'Sure enough I was right',
#   'as he continued to stare off into space',
#   'You can select your crust thickness',
#   'quick',
#   'and filling meal',
#   'the place was a great concept and had options for vegans until i saw them fingering meats and veggies without changing gloves',
#   'that is just unsanitary on a food quality level',
#   'Perfect spot for dinners with our whole family so the meat eaters still get meat',
#   'and were stoked when the State St location opened',
#   'Horribly slow',
#   'They prioritize their deliveries and make anyone that comes in just wait and wait',
#   'the computer in the back',
#   'wifi next door ( " Luna Grill Free Wifi " ) and I think the next time we \' ll just eat there instead',
#   'Patxis thin crust is the cost of a full meal out but even a large at $ 32 is only enough for one person bc its so thin and no toppings',
#   'staff super great',
#   'They are doing a really great job here',
#   'They acted like it was my fault and were not very accommodating',
#   'The brownies are REALLY good',
#   'Probably not worth the wait on free',
#   'or other specials days',
#   'but Blaze is simply really good at it',
#   'especially around dinner time',
#   "There is a disconnect between the app and the store ' s production timing",
#   'My favorite thing was how these young kids were working not playing on phones or gossiping',
#   'Surprised to know that was my pizza 1 / 2 done and explained I had already requested changes ( usually employees engage customers in the pizza process )',
#   'a Hawaiian pizza ( Canadian Bacon and Pineapple )',
#   'They were amazing ^ _ ^',
#   'Went to this location at 9 : 30 pm on a Thursday',
#   'Walked in and one of the staff was preparing mobile orders and another was prepping the dough',
#   'one side of the pizza got completely burnt ( see picture )',
#   'All staff present were not wearing name tags either',
#   'We can never agree on what to put on a pizza',
#   'so this works perfect for the two of us',
#   'and perfect crust',
#   'I went in late at night around 9 : 10 and waited and waited for my two pizzas',
#   'my name was called but I was outside and nobody ever came to tell me that my food was ready and I never heard my name called',
#   'Add a speaker outside that way we can hear our names being called',
#   'Not this location in particular : all blaze pizza sucks',
#   'thee crust is the worst offense to the senses : It is floppy',
#   'dough - ey',
#   'quick',
#   'relatively healthy',
#   'super helpful young staff',
#   'All the pizzas I ordered ( except one ) was under cooked',
#   'that gets it right every time',
#   'most definitely a great worker and what people look for',
#   'If your wanting a quick bite to eat',
#   "They move so slow it ' s painful",
#   'after being baked in the woodfired oven',
#   'absorbs all the flavors and juice from the toppings',
#   'Besides soft drinks',
#   'which as you all know is misery for a day or two',
#   'my partner is not',
#   'When we ordered it was right before they started carrying their new large size',
#   'Our first time ordering',
#   'like a cracker',
#   'ON A CRACKER',
#   'On our second order',
#   'two pizzas that were small - ish ( 11inchs',
#   'but adjust for shrinkage ) came to over $ 30',
#   'Value to quality = insert poop emoji here',
#   "in layman ' s terms",
#   "it ' s hard to overlook this disappointment",
#   'Forget Chik - Fil - A',
#   'Forget your whole life until this point : this Blaze pizza is flameo hotman',
#   'A raging inferno of superb customer service is contained within the walls of this establishment',
#   'I applaud your wise decision',
#   'and they make sure that they become your new flame ( :',
#   'We ordered pick - up from the Blaze app',
#   'By the time we got back to our hotel ( about 5 minutes away )',
#   'She was comely and professionally told that she would be made another and apologized to',
#   'They are not high end gourmet pizza but super tasty and satisfying for a pizza craving',
#   'The staff is always nice and attentive',
#   'And she just threw it back into the oven',
#   "he ' s always stressing out and cussing under his breath",
#   'the person making our pizzas took forever to put on each topping',
#   'Not many options in town for vegan pizzas but this place is nice',
#   'Blew me away on how quick it cooked',
#   'Nice staff',
#   'The staff is really nice & they are pretty fast at cooking your pizza',
#   "Staff was super friendly and we ' re very good at guiding you through the process of choosing a ton of different toppings / add ons",
#   'Seating is a little cramped and has a weird layout and they should add one more trash receptacle towards the back',
#   'we were checked in on twice',
#   'Customize your pizza for only $ 9',
#   '00 Quick',
#   'though none of them are organic',
#   "there ' s like 13 kids working and doing absolutely nothing",
#   'Gorgonzola and red onion taste like fart',
#   'This place is set up like an assembly line with all the toppings and sauces behind a glass wall you choose from',
#   'This is great'],
#  'anecdotes/miscellaneous': ['roasted garlic',
#   'At $ 3',
#   'IMHO',
#   'Tatiana',
#   'He said he was the manager',
#   'especially Tatiana',
#   'not great',
#   'it is like Wonder bread compared to artisan bakery bread',
#   'Upon arriving',
#   'unfortunately',
#   'Best pizza we have EVER had',
#   'and their salad is pretty good too',
#   'everything not only looks',
#   'e',
#   'Coca - Cola',
#   'sprite',
#   'Today',
#   'may 22nd',
#   'Thank you for the delicious food',
#   'not terrible',
#   'but you could smell it inside',
#   'about to go to the oven',
#   'Then',
#   'Sorry Blaze',
#   'Not only does Blaze have delicious food',
#   'Pizza Rev',
#   'Awful',
#   'Horrible after taste',
#   'Blaze pizza aka Blasé pizza',
#   'The best',
#   'Seriously',
#   "It will taste better and you won ' t have to deal with teenagers",
#   'However',
#   'Solid 3 stars',
#   'Not bad',
#   'not loaded with very many toppings',
#   'no biggie',
#   'Overall',
#   'Definitely',
#   'filling',
#   'EXCEPT the chocolate chip cookies',
#   'Not worth the calories',
#   'The rest of the crew was very helpful',
#   'Wonderfully pleasant team',
#   'Heck yeah',
#   'WHAT',
#   'affordable',
#   '25',
#   'Not the friendliest',
#   'Good pizza',
#   'We highly recommend Blaze',
#   'Not only that the prices are PERFECT',
#   'along with a side salad',
#   'The cashier seemed stoned',
#   'What that mean exactly',
#   'and the prices are fantastic',
#   'Also',
#   '$ 8',
#   'They also have beer options and gluten free crust',
#   'the flavors not bad',
#   'Wow',
#   'A Hello welcome to Blaze',
#   'Well',
#   'Well',
#   'OK',
#   'Annoying',
#   'but not the end of the world',
#   'That makes a total of $ 77',
#   "it ' s mediocre pizza",
#   'be my guest',
#   'especially the large selection of fresh vegetables',
#   'Not only is the pizza delicious',
#   'Bobby',
#   'Cheap',
#   'By the way',
#   "don ' t forget the strawberry salad with the dressing on the side",
#   'Enjoy',
#   'Five stars',
#   'Way to go Blaze State Street',
#   'Today just seemed minimally lacking',
#   "Let ' s just say",
#   'Well',
#   'Well',
#   'Bad energy',
#   'However',
#   'and very good pizza',
#   'The pizzas never disappoint',
#   'With a staff of 6',
#   'Horrible',
#   'disappointing',
#   'Disappointing',
#   'one Keto',
#   'Luckily',
#   'However',
#   'the other two pizzas were ridiculously burned',
#   'especially given the plethora of other options in town',
#   'Not good pizza',
#   'Not the best pizza ever',
#   "it ' s easy and cheap",
#   'not terrible',
#   'but you could smell it inside',
#   'about to go to the oven',
#   'Then',
#   'Sorry Blaze',
#   'Ok',
#   'best straight out the oven',
#   'online only',
#   'im not a fan of the plastic cups for the beer',
#   'other than that',
#   'great',
#   'what',
#   'Had a pizza for lunch three days ago',
#   'The model',
#   'esp',
#   'the Rev',
#   'until today',
#   'choose Blaze',
#   'Overall',
#   'he said he had one other delivery first',
#   'especially for the quality',
#   'and taste of the food',
#   'pizza sauce',
#   'veggies',
#   'meats',
#   'affordable',
#   'V',
#   'Last night was the worst',
#   'Hopefully the I',
#   'V',
#   'However',
#   'Also',
#   'open',
#   'Ciao',
#   'quality',
#   'efficiency',
#   'BOGO',
#   'Great job',
#   'Now',
#   'Easy online order with contact free pickup',
#   'Good vegan and gluten free options and super easy to customize',
#   'Will return',
#   'While in the oven',
#   'You pick the crust',
#   'you pick the sauce',
#   'you pick the toppings',
#   'Totally worth it',
#   'Apparently',
#   'Blaze pizza sucks',
#   'thick',
#   'My 7 yr pol son says',
#   'blaze pizza is the place',
#   'Yummmmy',
#   'Good pizza',
#   'Long lines',
#   'Wow wow wow gluten free pizza and the topping selection was amazing',
#   'Like the first time',
#   'besides the delivery fee itself',
#   "you won ' t get burned",
#   'and needless to say',
#   'Unfortunately',
#   'it better be palatable',
#   'Otherwise',
#   'just quit',
#   'The manager Bobby has an attitude and scolds his employees in front of customers',
#   'POOR QUALITY',
#   'Came here the other night and it took 25 minutes to order',
#   'Possibly the online orders',
#   'Vegan cheese',
#   "figured it couldn ' t hurt to try it out",
#   'The line moved very quickly',
#   'a ton of Parm',
#   'The selection of lemonades looked great',
#   '25',
#   'Convenient',
#   'good parking',
#   'good price',
#   'definitely recommend',
#   'good',
#   'Lol',
#   'You get to select everything',
#   'sauce',
#   'toppings'],
#  'price': ['Crust was a little underdone on mine',
#   'The service was quick and the staff was attentive',
#   'the entire thing was covered and there was no mozzerella',
#   'there was hair in 3 of the 4 pizzas',
#   'When it was my turn to pay The register girl Jay was very rude',
#   'She looks like she hates her job',
#   'This really was a 5 star trip',
#   'again it was painful for them to perform this task',
#   'service was fast',
#   'Service was very poor',
#   'the kids pizza was fine',
#   'Definitely was a great first time experience and will be coming back',
#   'luckily there was a short line',
#   "The guy there was apologetic and said he ' d see what he could do",
#   'Ingredients are fresh with a wide variety to pick from',
#   'The entire crust was burnt',
#   'we tried their $ 9 pizza which was a really thin crust',
#   'It was like a pizza hut personal sized pizza',
#   'and my partner said his non - vegan pizza was nothing to write home about',
#   'but ours was the opposite',
#   'The crust was a bit underdone and soggy / floppy',
#   'The manager politely told her to go around and to please be respectful and kind to those around her'],
#  'ambience': ['5 leaves of basil used when I asked for it as a topping',
#   'The restaurant was clean as well',
#   "the worker at the register shrugged his shoulders and said he didn ' t care",
#   "I ' ve been to many Blaze locations and when the state street location first opened",
#   'look at the picture uploaded by Cheng L',
#   "It ' s line style so you can see all the different ingredients available to you so that you know exactly what you ' re getting",
#   'I encourage you to go as soon as you get a chance',
#   'Also in the middle of me eating pizza the two super nice ladies came back to see if me and my co - worker was doing alright',
#   'As much as I love Blaze pizza',
#   'only one girls who was both taking the order and starting the pizzas',
#   "I ' ve been to this location many times since it ' s opened",
#   "As far as the pizza goes it ' s pretty good",
#   'Such a good idea and a great price for as many toppings as you want',
#   'I would give them a 2 out of 5 stars',
#   'you build it for $ 8',
#   'I asked for a little extra sausage',
#   'Chose any and as many toppings as you like',
#   'Keep up the great work',
#   'We have had a few issues as to the accuracy of our orders but all in all they made up for it and the pizza in terrific',
#   '95 for a pizza with AS MANY toppings as you want',
#   'Thanks Blaze for a great experience',
#   'who often works the oven',
#   'I only wanted a slice of pizza',
#   "The power is out but they still managed to get one last pizza in for me and then comp ' d me a desert",
#   'but not as good as Persona',
#   'overall the some of the servers looked new',
#   'I ordered 2 whole pizza and 1 half along with 2 glass bottles sodas',
#   'Ordered two pizzas and they were very doughy with toppings that were lot flavorful and on most of the pizzas rather sparse',
#   'As much as I love Blaze pizza',
#   'only one girls who was both taking the order and starting the pizzas',
#   "I ' ve been to this location many times since it ' s opened",
#   'as the garlic flatulence went on for two hours',
#   "but continue to make everyone else ' s pizza",
#   'the dressing really complimented the strong taste of arugula',
#   "an hour and 46 minutes after order and about an hour after we decided to go to the market and cook a frozen ' zza",
#   'By 8 : 45',
#   'as many as you want',
#   'and they also have salads and desserts as well',
#   'The service was super fast and friendly as well',
#   "I ' d give the restaurant five stars but there ' s a cheesy salad next to the classic red sauce that occasionally spills in",
#   'All you get are instructions on how to complain online and how hard it is for them to answer the phone at the locations',
#   'some servers move less quickly than others',
#   'The pizzas at blaze are individual sized but i couldnt even finish my whole pizza and im a big eater',
#   'A + + + for value',
#   'Very generous with toppings',
#   'As someone who has medical dietary restrictions',
#   'The young man Tyler',
#   'The gf crust was rolled as thin as a tortilla',
#   'Stood there for 5 min with ZERO acknowledgement',
#   'I wanted a custom salad on top of the pizza instead of the arugula salad that they prepare with strawberries and goat cheese',
#   'You get to see your own pizza built in front of you',
#   'Very friendly workers as well',
#   'While Blaze makes some good pizzas',
#   'with Diego vehemently fanning the flames',
#   'Thankfully the room we are staying in had a microwave',
#   "work for Mickey D ' s",
#   'Recently the quality control has been horrible',
#   'Such a great spot',
#   'most impressed at the new State Steet location',
#   'you can also add to their already listed signature pizzas',
#   'The combination of broccoli',
#   'They have a giant pizza oven that fits several pizzas']}

# %% [markdown]
# #### Threshold will need to be further fine tuned. This was just a general proof of concept for one restaurant.
# <br>
# <br>
# <br>

# %% [markdown]
# ### Retrieve phrases to understand how model is performing on classification.

# %%
# Define a function to search for a text component and retrieve corresponding prediction
def retrieve_segment_and_prediction(all_predictions, search_text_component):
    for segment_texts, segment_predictions in all_predictions:
        for text, prediction in zip(segment_texts, segment_predictions):
            if search_text_component in text:
                return text, prediction
    # If the text component is not found, return None
    return None, None

# Example usage:
search_text_component = "the service was always fast and friendly but lately we"  # Replace "example" with the text component you want to search for
segment_text, segment_prediction = retrieve_segment_and_prediction(all_predictions, search_text_component)

if segment_text is not None:
    print("Segment Text:", segment_text)
    print("Corresponding Prediction:", segment_prediction)
else:
    print("Text component not found in any segment.")
# Out:
# Segment Text: as the service was always fast and friendly but lately we ' ve noticed a disappointing decline in the customer service
# Corresponding Prediction: [0.21523188 0.81354433 0.10245086 0.04549364 0.6187326 ]

# %% [markdown]
# #### There is much room for improvement. In this example, the segment is being allocated to the Food topic instead of the Service topic. Training dataset likely needs to be larger, and more balanced. Additionally, an even more robust model with transformer architecture, such as BERT and ChatGPT would likely also increase performance.
# <br>
# <br>

# %% [markdown]
# ### Continuing proof of concept by applying a Sentiment Analyzer to text in each topic

# %%
# Initialize SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# Dictionary to store sentiment scores for each topic
sentiment_scores = {topic: [] for topic in topics}

# Iterate through topics and corresponding texts
for topic, texts in tokens_for_labels.items():
    for text in texts:
        # Calculate sentiment scores for each text
        sentiment_score = sia.polarity_scores(text)
        sentiment_scores[topic].append(sentiment_score)

# Check
for topic, scores in sentiment_scores.items():
    print(f"{topic} sentiment scores: {scores[:10]}")
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Caitl\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# service sentiment scores: [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.105, 'neu': 0.608, 'pos': 0.287, 'compound': 0.5106}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.645, 'pos': 0.355, 'compound': 0.6705}, {'neg': 0.165, 'neu': 0.57, 'pos': 0.266, 'compound': 0.3818}, {'neg': 0.307, 'neu': 0.693, 'pos': 0.0, 'compound': -0.6113}, {'neg': 0.0, 'neu': 0.526, 'pos': 0.474, 'compound': 0.4019}]
# food sentiment scores: [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.2, 'neu': 0.8, 'pos': 0.0, 'compound': -0.3612}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.506, 'pos': 0.494, 'compound': 0.4466}, {'neg': 0.0, 'neu': 0.441, 'pos': 0.559, 'compound': 0.5859}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.423, 'pos': 0.577, 'compound': 0.6249}]
# anecdotes/miscellaneous sentiment scores: [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.767, 'neu': 0.233, 'pos': 0.0, 'compound': -0.5096}, {'neg': 0.0, 'neu': 0.783, 'pos': 0.217, 'compound': 0.3612}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.34}]
# price sentiment scores: [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.196, 'neu': 0.804, 'pos': 0.0, 'compound': -0.296}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.281, 'neu': 0.719, 'pos': 0.0, 'compound': -0.5709}, {'neg': 0.279, 'neu': 0.481, 'pos': 0.24, 'compound': -0.1027}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.244, 'neu': 0.756, 'pos': 0.0, 'compound': -0.4404}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.531, 'neu': 0.469, 'pos': 0.0, 'compound': -0.5256}]
# ambience sentiment scores: [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.455, 'pos': 0.545, 'compound': 0.5859}, {'neg': 0.0, 'neu': 0.789, 'pos': 0.211, 'compound': 0.4939}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.602, 'pos': 0.398, 'compound': 0.6486}, {'neg': 0.0, 'neu': 0.726, 'pos': 0.274, 'compound': 0.8271}, {'neg': 0.0, 'neu': 0.543, 'pos': 0.457, 'compound': 0.6369}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}]

# %% [markdown]
# ### Averaging sentiment scores within each topic for a generalized sentiment score for each

# %%
# Dictionary to store overall sentiment scores for each topic
overall_sentiment_scores = {}

# Iterate through topics and corresponding sentiment scores
for topic, scores in sentiment_scores.items():
    # Calculate the sum of compound scores for each topic
    compound_sum = sum(score['compound'] for score in scores)
    # Calculate the average compound score for each topic
    num_scores = len(scores)
    average_compound_score = compound_sum / num_scores
    overall_sentiment_scores[topic] = average_compound_score

# Check
for topic, average_score in overall_sentiment_scores.items():
    print(f"{topic} overall sentiment score (average): {average_score}")
# Out:
# service overall sentiment score (average): 0.15729909365558886
# food overall sentiment score (average): 0.16541710526315784
# anecdotes/miscellaneous overall sentiment score (average): 0.09867857142857142
# price overall sentiment score (average): 0.04827727272727273
# ambience overall sentiment score (average): 0.19590322580645161

# %% [markdown]
# ***
# #### Once model is in a good place after many iterations with different restaurants, and improvements mentioned above, you could use the ouput above for analysis. In this example, you could maybe conclude there is a mismatch between price and what a customer is getting food-wise and service-wise. However in the model's current state, you likely could not feel confident in its analysis.

# %%
# Out:
# Number of rows where service = 1: 746
# Number of rows where food = 1: 1600
# Number of rows where anecdotes/miscellaneous = 1: 1335
# Number of rows where price = 1: 359
# Number of rows where ambience = 1: 487
